# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
slucajevi_df = pd.read_csv("casedistribution.csv", parse_dates=["dateRep"])

slucajevi_df.head(3)
# Out:
# C:\Users\brankor\AppData\Local\Temp\ipykernel_25676\1870064622.py:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   slucajevi_df = pd.read_csv("casedistribution.csv", parse_dates=["dateRep"])
#      dateRep  day  month  year  cases  deaths countriesAndTerritories geoId  \
# 0 2020-12-14   14     12  2020    746       6             Afghanistan    AF
# 1 2020-12-13   13     12  2020    298       9             Afghanistan    AF
# 2 2020-12-12   12     12  2020    113      11             Afghanistan    AF
#
#   countryterritoryCode  popData2019 continentExp  \
# 0                  AFG   38041757.0         Asia
# 1                  AFG   38041757.0         Asia
# 2                  AFG   38041757.0         Asia
#
#    Cumulative_number_for_14_days_of_COVID-19_cases_per_100000
# 0                                           9.013779
# ...

# %%
slucajevi_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61900 entries, 0 to 61899
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     61900 non-null  datetime64[ns]
#  1   day                                                         61900 non-null  int64
#  2   month                                                       61900 non-null  int64
#  3   year                                                        61900 non-null  int64
#  4   cases                                                       61900 non-null  int64
#  5   deaths                                                      61900 non-null  int64
#  6   countriesAndTerritories                                     61900 non-null  object
# ...

# %%
slucajevi_po_danu = slucajevi_df[["dateRep", "cases"]].groupby(by="dateRep", as_index=False).sum()
slucajevi_po_danu.sort_values(by="dateRep", inplace=True)
slucajevi_po_danu
# Out:
#        dateRep   cases
# 0   2019-12-31      27
# 1   2020-01-01       0
# 2   2020-01-02       0
# 3   2020-01-03      17
# 4   2020-01-04       0
# ..         ...     ...
# 345 2020-12-10  676114
# 346 2020-12-11  693352
# 347 2020-12-12  657140
# 348 2020-12-13  626421
# 349 2020-12-14  540659
#
# [350 rows x 2 columns]

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases)

# %%
mix_datuma = slucajevi_po_danu.sample(frac=1)
mix_datuma
# Out:
#        dateRep   cases
# 8   2020-01-08       0
# 157 2020-06-05  127354
# 22  2020-01-22     142
# 201 2020-07-19  227019
# 71  2020-03-11    5117
# ..         ...     ...
# 101 2020-04-10   87409
# 105 2020-04-14   65259
# 9   2020-01-09       0
# 286 2020-10-12  304057
# 127 2020-05-06   79558
#
# [350 rows x 2 columns]

# %%
plt.plot(mix_datuma.dateRep, mix_datuma.cases)

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, ".:m")

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, "o:k")

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, ".-.r")

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, "X r")

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, "X-r")

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, "X--r")

# %%
plt.rcParams["figure.figsize"] = [9, 8]
plt.rcParams["figure.dpi"] = 100

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, "X--r")

# %%
plt.rcdefaults()

# %%
plt.plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases, "X--r")

# %%
okvir = plt.figure()

# %%
okvir = plt.figure(figsize=(8, 8))
vanjski_graf = okvir.add_axes((0.1, 0.1, 0.9, 0.9))
unutarnji_graf = okvir.add_axes((0.7, 0.7, 0.2, 0.1))

# %%
okvir = plt.figure(figsize=(8, 8))
grid_space = okvir.add_gridspec(3, 3)

gore_lijevo = okvir.add_subplot(grid_space[0, 0])
srednje_lijevo = okvir.add_subplot(grid_space[1, 0])
gore_desno = okvir.add_subplot(grid_space[:2, 1:])
dolje = okvir.add_subplot(grid_space[2, :])

# %%
okvir, osi = plt.subplots(1, 2)

# %%
slucajevi_df_mean = slucajevi_df[["dateRep","cases"]].groupby(by="dateRep", as_index=False).mean()
slucajevi_df_mean.sort_values(by="dateRep", inplace=True)

osi[0].plot(slucajevi_po_danu.dateRep, slucajevi_po_danu.cases)
osi[1].plot(slucajevi_df_mean.dateRep, slucajevi_df_mean.cases)
okvir

# %%
kupci_df = pd.read_csv("mall_customers.csv")
kupci_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
kupci_df.plot()
# Out:
# <Axes: >

# %%
# kupci_df["Annual Income (k$)"] = 1000*kupci_df["Annual Income (k$)"] 
# kupci_df.plot()

# %%
kupci_score = kupci_df.iloc[:, [1, 2, 4]]
kupci_score
# Out:
#      Gender  Age  Spending Score (1-100)
# 0      Male   19                      39
# 1      Male   21                      81
# 2    Female   20                       6
# 3    Female   23                      77
# 4    Female   31                      40
# ..      ...  ...                     ...
# 195  Female   35                      79
# 196  Female   45                      28
# 197    Male   32                      74
# 198    Male   32                      18
# 199    Male   30                      83
#
# [200 rows x 3 columns]

# %%
kupci_prosjek_po_godinama = kupci_score.groupby(by="Age", as_index=False).mean(numeric_only=True)
kupci_prosjek_po_godinama
# Out:
#     Age  Spending Score (1-100)
# 0    18               60.000000
# 1    19               39.750000
# 2    20               40.200000
# 3    21               66.800000
# 4    22               70.000000
# 5    23               63.333333
# 6    24               71.500000
# 7    25               39.666667
# 8    26               54.500000
# 9    27               60.333333
# 10   28               70.000000
# 11   29               76.600000
# 12   30               80.285714
# 13   31               63.875000
# 14   32               66.000000
# 15   33               54.333333
# 16   34               39.200000
# 17   35               63.888889
# 18   36               52.500000
# 19   37               15.333333
# 20   38               63.166667
# 21   39               84.666667
# 22   40               47.500000
# 23   41               28.000000
# 24   42               18.500000
# 25   43               34.000000
# 26   44               13.500000
# 27   45               37.666667
# ...

# %%
kupci_prosjek_po_godinama.columns
# Out:
# Index(['Age', 'Spending Score (1-100)'], dtype='object')

# %%
kupci_prosjek_po_godinama.plot(
    kind="line",
    x="Age",
    y="Spending Score (1-100)",
    figsize=(10, 5),
    style="o--b",
    legend=True,
    title="Srednja vrijednost bodovanja po godinama"
    )
# Out:
# <Axes: title={'center': 'Srednja vrijednost bodovanja po godinama'}, xlabel='Age'>

# %%
kupci_df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
kupci_df.groupby(by="Age", as_index=False).mean(numeric_only=True).plot(
    kind="line",
    x="Age",
    y=["Spending Score (1-100)", "Annual Income (k$)"],
    figsize=(10, 5),
    style=["o--b", "x:g"],
    legend=True,
    title="Srednja vrijednost bodovanja po godinama"
)
# Out:
# <Axes: title={'center': 'Srednja vrijednost bodovanja po godinama'}, xlabel='Age'>

# %%
kupci_df.groupby(by="Age", as_index=False).mean(numeric_only=True).plot(
    kind="line",
    x="Age",
    y=["Spending Score (1-100)", "Annual Income (k$)"],
    subplots=True,
    layout=(1, 2),
    figsize=(10, 5),
    style=["o--b", "x:g"],
    legend=True,
    title="Srednja vrijednost bodovanja po godinama"
)
# Out:
# array([[<Axes: xlabel='Age'>, <Axes: xlabel='Age'>]], dtype=object)

# %%
kupci_df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
kupci_df.groupby(by="Age", as_index=False).mean(numeric_only=True).plot(
    kind="line",
    x="Age",
    y=["Spending Score (1-100)", "Annual Income (k$)", "CustomerID"],
    subplots=True,
    layout=(1, 3),
    figsize=(12, 5),
    style=["o--b", "x:g", ":m"],
    legend=True,
    title="Srednja vrijednost bodovanja po godinama"
)
# Out:
# array([[<Axes: xlabel='Age'>, <Axes: xlabel='Age'>, <Axes: xlabel='Age'>]],
#       dtype=object)

# %%
kupci_df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
kupci_po_spolu_godinama = kupci_df[['Gender', 'Age', 'Spending Score (1-100)']]
kupci_po_spolu_godinama
# Out:
#      Gender  Age  Spending Score (1-100)
# 0      Male   19                      39
# 1      Male   21                      81
# 2    Female   20                       6
# 3    Female   23                      77
# 4    Female   31                      40
# ..      ...  ...                     ...
# 195  Female   35                      79
# 196  Female   45                      28
# 197    Male   32                      74
# 198    Male   32                      18
# 199    Male   30                      83
#
# [200 rows x 3 columns]

# %%
prosjek_po_godinama_score = kupci_po_spolu_godinama.pivot_table(index="Age", columns="Gender", values="Spending Score (1-100)", aggfunc="mean")
prosjek_po_godinama_score.head(5)
# Out:
# Gender  Female       Male
# Age
# 18       48.00  64.000000
# 19       52.00  35.666667
# 20       40.50  40.000000
# 21       63.25  81.000000
# 22       65.50  79.000000

# %%
prosjek_po_godinama_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 18 to 70
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Female  43 non-null     float64
#  1   Male    44 non-null     float64
# dtypes: float64(2)
# memory usage: 1.2 KB

# %%
prosjek_po_godinama_score.isnull().sum()
# Out:
# Gender
# Female    8
# Male      7
# dtype: int64

# %%
prosjek_po_godinama_score.loc[40:50]
# Out:
# Gender     Female  Male
# Age
# 40      43.000000  52.0
# 41      28.000000   NaN
# 42      17.000000  20.0
# 43      50.000000  26.0
# 44      13.500000   NaN
# 45      37.666667   NaN
# 46      24.500000  15.0
# 47      30.250000  25.0
# 48            NaN  41.8
# 49      40.500000  56.0
# 50      50.750000  26.0

# %%
rolling_po_godnama = prosjek_po_godinama_score.rolling(3, min_periods=1).mean()
rolling_po_godnama.head(5)
# Out:
# Gender     Female       Male
# Age
# 18      48.000000  64.000000
# 19      50.000000  49.833333
# 20      46.833333  46.555556
# 21      51.916667  52.222222
# 22      56.416667  66.666667

# %%
rolling_po_godnama.loc[40:50]
# Out:
# Gender     Female       Male
# Age
# 40      52.625000  67.222222
# 41      35.500000  68.333333
# 42      29.333333  36.000000
# 43      31.666667  23.000000
# 44      26.833333  23.000000
# 45      33.722222  26.000000
# 46      25.222222  15.000000
# 47      30.805556  20.000000
# 48      27.375000  27.266667
# 49      35.375000  40.933333
# 50      45.625000  41.266667

# %%
(48 + 52+40.5)/3
# Out:
# 46.833333333333336

# %%
okvir, osi = plt.subplots(1, 2, figsize=(15,5))

rolling_po_godnama[["Male"]].plot(ax=osi[0], color="g")
rolling_po_godnama[["Female"]].plot(ax=osi[1], color="r")
# Out:
# <Axes: xlabel='Age'>

# %%
okvir, osi = plt.subplots(1, 2, figsize=(15,5))

prosjek_po_godinama_score[["Male"]].plot(ax=osi[0], color="g")
prosjek_po_godinama_score[["Female"]].plot(ax=osi[1], color="r")
# Out:
# <Axes: xlabel='Age'>

# %%
prosjek_po_godinama_score[["Male"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 51 entries, 18 to 70
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Male    44 non-null     float64
# dtypes: float64(1)
# memory usage: 2.9 KB

# %%
odbaci_missing = prosjek_po_godinama_score.dropna()

# %%
okvir, osi = plt.subplots(1, 2, figsize=(15,5))

odbaci_missing[["Male"]].plot(ax=osi[0], color="g")
odbaci_missing[["Female"]].plot(ax=osi[1], color="r")
# Out:
# <Axes: xlabel='Age'>

# %%
odbaci_missing.columns
# Out:
# Index(['Female', 'Male'], dtype='object', name='Gender')

# %%
okvir, osi = plt.subplots(1, 2, figsize=(15,8))

osi[0].scatter(odbaci_missing.index, odbaci_missing.Male, label='Zenski Podatci', color='blue', marker='x',  s=70)
osi[0].set_title('Muski Podatci Distribucija')
osi[0].set_xlabel('Godine')
osi[0].set_ylabel('Score (1-100)')
osi[0].legend()

osi[1].scatter(odbaci_missing.index, odbaci_missing.Female, label='Zenski Podatci', color='blue', marker='o', s = 50)
osi[1].set_title('Zenski Podatci Distribucija')
osi[1].set_xlabel('Godine')
osi[1].set_ylabel('Score (1-100)')
osi[1].legend()

# %%
kupci_df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
kupci_df.plot(kind="scatter", x='Annual Income (k$)', y='Spending Score (1-100)', xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
kupci_df.plot.scatter(x='Annual Income (k$)', y='Spending Score (1-100)', xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)')
# Out:
# <Axes: xlabel='Annual Income (k$)', ylabel='Spending Score (1-100)'>

# %%
kupci_df.plot.hist(y='Spending Score (1-100)', ylabel="Broj bodova", xlabel="Ocjene", bins=150)
# Out:
# <Axes: xlabel='Ocjene', ylabel='Broj bodova'>

# %%
kupci_df.plot.hist(y='Spending Score (1-100)', ylabel="Broj bodova", xlabel="Ocjene", bins=10)
# Out:
# <Axes: xlabel='Ocjene', ylabel='Broj bodova'>

# %%
kupci_df.plot.hist(y='Spending Score (1-100)', ylabel="Broj bodova", xlabel="Ocjene", bins=3)
# Out:
# <Axes: xlabel='Ocjene', ylabel='Broj bodova'>

# %%
ocjene_df = pd.read_csv('ocjene.csv')
ocjene_df
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
ocjene_df.plot.scatter(x="hours", y="grade")
# Out:
# <Axes: xlabel='hours', ylabel='grade'>

# %%
ocjene_df.corr(numeric_only=True)
# Out:
#                age  exercise     hours     grade
# age       1.000000 -0.003643 -0.017467 -0.007580
# exercise -0.003643  1.000000  0.021105  0.161286
# hours    -0.017467  0.021105  1.000000  0.801955
# grade    -0.007580  0.161286  0.801955  1.000000

# %%
ocjene_df.plot.box()
# Out:
# <Axes: >

# %%
ocjene_df.describe(include="all")["grade"]
# Out:
# count     2000.000000
# unique            NaN
# top               NaN
# freq              NaN
# mean        82.556050
# std          9.747593
# min         32.000000
# 25%         75.575000
# 50%         82.700000
# 75%         89.700000
# max        100.000000
# Name: grade, dtype: float64

# %%
zemljotresi = pd.read_csv("earthquakes.csv")
zemljotresi
# Out:
#      alert  cdi        code  \
# 0      NaN  NaN    37389218
# 1      NaN  NaN    37389202
# 2      NaN  4.4    37389194
# 3      NaN  NaN    37389186
# 4      NaN  NaN    73096941
# ...    ...  ...         ...
# 9327   NaN  NaN    73086771
# 9328   NaN  NaN    38063967
# 9329   NaN  NaN  2018261000
# 9330   NaN  NaN    38063959
# 9331   NaN  NaN    38063935
#
#                                                  detail      dmin  felt  \
# 0     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.008693   NaN
# 1     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.020030   NaN
# 2     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.021370  28.0
# 3     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.026180   NaN
# 4     https://earthquake.usgs.gov/fdsnws/event/1/que...  0.077990   NaN
# ...                                                 ...       ...   ...
# 9327  https://earthquake.usgs.gov/fdsnws/event/1/que...  0.018060   NaN
# ...

# %%
zemljotresi.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
zemljotresi[["mag", "magType"]]
# Out:
#        mag magType
# 0     1.35      ml
# 1     1.29      ml
# 2     3.42      ml
# 3     0.44      ml
# 4     2.16      md
# ...    ...     ...
# 9327  0.62      md
# 9328  1.00      ml
# 9329  2.40      md
# 9330  1.10      ml
# 9331  0.66      ml
#
# [9332 rows x 2 columns]

# %%
zemljotresi[["mag", "magType"]].groupby("magType").boxplot(figsize=(15,8), subplots=False)
# Out:
# <Axes: >

# %%
zemljotresi[["mag", "magType"]].groupby("magType").boxplot(figsize=(15,8), subplots=False, notch=True)
# Out:
# <Axes: >

# %%
zemljotresi.columns
# Out:
# Index(['alert', 'cdi', 'code', 'detail', 'dmin', 'felt', 'gap', 'ids', 'mag',
#        'magType', 'mmi', 'net', 'nst', 'place', 'rms', 'sig', 'sources',
#        'status', 'time', 'title', 'tsunami', 'type', 'types', 'tz', 'updated',
#        'url'],
#       dtype='object')

# %%
zemljotresi.place
# Out:
# 0                  9km NE of Aguanga, CA
# 1                  9km NE of Aguanga, CA
# 2                  8km NE of Aguanga, CA
# 3                  9km NE of Aguanga, CA
# 4                  10km NW of Avenal, CA
#                       ...
# 9327        9km ENE of Mammoth Lakes, CA
# 9328                 3km W of Julian, CA
# 9329    35km NNE of Hatillo, Puerto Rico
# 9330               9km NE of Aguanga, CA
# 9331               9km NE of Aguanga, CA
# Name: place, Length: 9332, dtype: object

# %%
zemljotresi.place.unique()
# Out:
# array(['9km NE of Aguanga, CA', '8km NE of Aguanga, CA',
#        '10km NW of Avenal, CA', ..., '9km ENE of Mammoth Lakes, CA',
#        '3km W of Julian, CA', '35km NNE of Hatillo, Puerto Rico'],
#       dtype=object)

# %%
zemljotresi.place.unique().shape
# Out:
# (5433,)

# %%
zemljotresi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 26 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   alert    59 non-null     object
#  1   cdi      329 non-null    float64
#  2   code     9332 non-null   object
#  3   detail   9332 non-null   object
#  4   dmin     6139 non-null   float64
#  5   felt     329 non-null    float64
#  6   gap      6164 non-null   float64
#  7   ids      9332 non-null   object
#  8   mag      9331 non-null   float64
#  9   magType  9331 non-null   object
#  10  mmi      93 non-null     float64
#  11  net      9332 non-null   object
#  12  nst      5364 non-null   float64
#  13  place    9332 non-null   object
#  14  rms      9332 non-null   float64
#  15  sig      9332 non-null   int64
#  16  sources  9332 non-null   object
#  17  status   9332 non-null   object
#  18  time     9332 non-null   int64
#  19  title    9332 non-null   object
# ...

# %%
zemljotresi.place.value_counts()
# Out:
# place
# 10km NE of Aguanga, CA                   306
# 9km NE of Aguanga, CA                    264
# 42km ENE of Adak, Alaska                  71
# 22km ENE of Honaunau-Napoopoo, Hawaii     65
# 8km NE of Aguanga, CA                     60
#                                         ...
# 73km NNW of Talkeetna, Alaska              1
# 25km ENE of Nikiski, Alaska                1
# 68km NNW of Talkeetna, Alaska              1
# 72km E of Cape Yakataga, Alaska            1
# 35km NNE of Hatillo, Puerto Rico           1
# Name: count, Length: 5433, dtype: int64

# %%
zemljotresi.place.value_counts().plot.bar(figsize=(10, 5), title="Mjesta potresa")
# Out:
# <Axes: title={'center': 'Mjesta potresa'}, xlabel='place'>

# %%
zemljotresi.place.value_counts().iloc[:10].plot.bar(figsize=(10, 5), title="Mjesta potresa")
# Out:
# <Axes: title={'center': 'Mjesta potresa'}, xlabel='place'>

# %%
zemljotresi.place.value_counts().iloc[:10].plot.barh(figsize=(10, 5), title="Mjesta potresa")
# Out:
# <Axes: title={'center': 'Mjesta potresa'}, ylabel='place'>

# %%
zemljotresi.place.value_counts().iloc[10::-1]

# %%
zemljotresi.place.value_counts().iloc[10::-1].plot.barh(figsize=(10, 5), title="Mjesta potresa")
# Out:
# <Axes: title={'center': 'Mjesta potresa'}, ylabel='place'>

# %%
zemljotresi_broj = zemljotresi.place.value_counts()
zemljotresi_broj
# Out:
# place
# 10km NE of Aguanga, CA                   306
# 9km NE of Aguanga, CA                    264
# 42km ENE of Adak, Alaska                  71
# 22km ENE of Honaunau-Napoopoo, Hawaii     65
# 8km NE of Aguanga, CA                     60
#                                         ...
# 73km NNW of Talkeetna, Alaska              1
# 25km ENE of Nikiski, Alaska                1
# 68km NNW of Talkeetna, Alaska              1
# 72km E of Cape Yakataga, Alaska            1
# 35km NNE of Hatillo, Puerto Rico           1
# Name: count, Length: 5433, dtype: int64

# %%
zemljotresi_broj.values
# Out:
# array([306, 264,  71, ...,   1,   1,   1], dtype=int64)

# %%
zemljotresi_broj.index
# Out:
# Index(['10km NE of Aguanga, CA', '9km NE of Aguanga, CA',
#        '42km ENE of Adak, Alaska', '22km ENE of Honaunau-Napoopoo, Hawaii',
#        '8km NE of Aguanga, CA', '7km NW of The Geysers, CA',
#        '9km NW of The Geysers, CA', '8km ENE of Aguanga, CA',
#        '9km ENE of Aguanga, CA', '78km SSW of Kaktovik, Alaska',
#        ...
#        '45km SW of Cantwell, Alaska', '23km NE of Goldfield, Nevada',
#        '62km SSW of Tok, Alaska', '18km SSE of Tallaboa, Puerto Rico',
#        '130km SE of Honiara, Solomon Islands', '73km NNW of Talkeetna, Alaska',
#        '25km ENE of Nikiski, Alaska', '68km NNW of Talkeetna, Alaska',
#        '72km E of Cape Yakataga, Alaska', '35km NNE of Hatillo, Puerto Rico'],
#       dtype='object', name='place', length=5433)

# %%
# plt.bar(x=zemljotresi_broj.values, y=zemljotresi_broj.index, height=0.8)

# %%
zemljotresi["mjesta"] = zemljotresi.place.str.replace(r".*, ", "" ,regex=True)

# %%
zemljotresi["mjesta"].unique()
# Out:
# array(['CA', 'Dominican Republic', 'Alaska', 'Indonesia', 'Canada',
#        'Puerto Rico', 'Montana', 'Nevada', 'Christmas Island', 'Hawaii',
#        'Northern Mariana Islands', 'Japan', 'California', 'Ecuador',
#        'Vanuatu', 'MX', 'Russia', 'British Virgin Islands', 'Washington',
#        'Papua New Guinea', 'South of the Fiji Islands',
#        'U.S. Virgin Islands', 'Chile', 'Peru', 'Yemen', 'NV', 'Guatemala',
#        'Kansas', 'Australia', 'Wyoming', 'East of the Kuril Islands',
#        'Oklahoma', 'Tennessee', 'Fiji', 'Pacific-Antarctic Ridge', 'Utah',
#        'Colombia', 'Argentina', 'Oregon', 'Greece', 'Missouri',
#        'Tajikistan', 'Northern Mid-Atlantic Ridge',
#        'Off the west coast of northern Sumatra', 'Solomon Islands',
#        'Burma', 'Taiwan', 'Nicaragua',
#        'South Georgia and the South Sandwich Islands', 'Idaho',
#        'Kyrgyzstan', 'Arizona', 'Tonga', 'Northern East Pacific Rise',
# ...

# %%
zemljotresi["mjesta"] = zemljotresi.mjesta.str.replace(r"CA$", "Califronia", regex=True).str.replace(r"NV$", "Nevada", regex=True).str.replace(r"MX$", "Mexico", regex=True)
# zemljotresi["mjesta"] = zemljotresi.mjesta.str.replace("CA$", "Califronia", regex=True)
# zemljotresi["mjesta"] = zemljotresi.mjesta.str.replace("NV$", "Nevada", regex=True)

# %%
zemljotresi["mjesta"].unique()
# Out:
# array(['Califronia', 'Dominican Republic', 'Alaska', 'Indonesia',
#        'Canada', 'Puerto Rico', 'Montana', 'Nevada', 'Christmas Island',
#        'Hawaii', 'Northern Mariana Islands', 'Japan', 'California',
#        'Ecuador', 'Vanuatu', 'Mexico', 'Russia', 'British Virgin Islands',
#        'Washington', 'Papua New Guinea', 'South of the Fiji Islands',
#        'U.S. Virgin Islands', 'Chile', 'Peru', 'Yemen', 'Guatemala',
#        'Kansas', 'Australia', 'Wyoming', 'East of the Kuril Islands',
#        'Oklahoma', 'Tennessee', 'Fiji', 'Pacific-Antarctic Ridge', 'Utah',
#        'Colombia', 'Argentina', 'Oregon', 'Greece', 'Missouri',
#        'Tajikistan', 'Northern Mid-Atlantic Ridge',
#        'Off the west coast of northern Sumatra', 'Solomon Islands',
#        'Burma', 'Taiwan', 'Nicaragua',
#        'South Georgia and the South Sandwich Islands', 'Idaho',
#        'Kyrgyzstan', 'Arizona', 'Tonga', 'Northern East Pacific Rise',
# ...

# %%
zemljotresi["mjesta"] = zemljotresi.mjesta.str.replace(".* of ", "", regex=True)

# %%
zemljotresi["mjesta"].unique()
# Out:
# array(['Califronia', 'Dominican Republic', 'Alaska', 'Indonesia',
#        'Canada', 'Puerto Rico', 'Montana', 'Nevada', 'Christmas Island',
#        'Hawaii', 'Northern Mariana Islands', 'Japan', 'California',
#        'Ecuador', 'Vanuatu', 'Mexico', 'Russia', 'British Virgin Islands',
#        'Washington', 'Papua New Guinea', 'the Fiji Islands',
#        'U.S. Virgin Islands', 'Chile', 'Peru', 'Yemen', 'Guatemala',
#        'Kansas', 'Australia', 'Wyoming', 'the Kuril Islands', 'Oklahoma',
#        'Tennessee', 'Fiji', 'Pacific-Antarctic Ridge', 'Utah', 'Colombia',
#        'Argentina', 'Oregon', 'Greece', 'Missouri', 'Tajikistan',
#        'Northern Mid-Atlantic Ridge', 'northern Sumatra',
#        'Solomon Islands', 'Burma', 'Taiwan', 'Nicaragua',
#        'South Georgia and the South Sandwich Islands', 'Idaho',
#        'Kyrgyzstan', 'Arizona', 'Tonga', 'Northern East Pacific Rise',
#        'Vanuatu region', 'South Africa', 'Southern Mid-Atlantic Ridge',
# ...

# %%
zemljotresi["mjesta"] = zemljotresi.mjesta.str.replace(r" region", "")

# %%
zemljotresi["mjesta"].unique()
# Out:
# array(['Califronia', 'Dominican Republic', 'Alaska', 'Indonesia',
#        'Canada', 'Puerto Rico', 'Montana', 'Nevada', 'Christmas Island',
#        'Hawaii', 'Northern Mariana Islands', 'Japan', 'California',
#        'Ecuador', 'Vanuatu', 'Mexico', 'Russia', 'British Virgin Islands',
#        'Washington', 'Papua New Guinea', 'the Fiji Islands',
#        'U.S. Virgin Islands', 'Chile', 'Peru', 'Yemen', 'Guatemala',
#        'Kansas', 'Australia', 'Wyoming', 'the Kuril Islands', 'Oklahoma',
#        'Tennessee', 'Fiji', 'Pacific-Antarctic Ridge', 'Utah', 'Colombia',
#        'Argentina', 'Oregon', 'Greece', 'Missouri', 'Tajikistan',
#        'Northern Mid-Atlantic Ridge', 'northern Sumatra',
#        'Solomon Islands', 'Burma', 'Taiwan', 'Nicaragua',
#        'South Georgia and the South Sandwich Islands', 'Idaho',
#        'Kyrgyzstan', 'Arizona', 'Tonga', 'Northern East Pacific Rise',
#        'South Africa', 'Southern Mid-Atlantic Ridge', 'Costa Rica',
# ...

# %%
zemljotresi["mjesta"] = zemljotresi.mjesta.str.replace(r" the ", "")

# %%
zemljotresi["mjesta"].unique()
# Out:
# array(['Califronia', 'Dominican Republic', 'Alaska', 'Indonesia',
#        'Canada', 'Puerto Rico', 'Montana', 'Nevada', 'Christmas Island',
#        'Hawaii', 'Northern Mariana Islands', 'Japan', 'California',
#        'Ecuador', 'Vanuatu', 'Mexico', 'Russia', 'British Virgin Islands',
#        'Washington', 'Papua New Guinea', 'the Fiji Islands',
#        'U.S. Virgin Islands', 'Chile', 'Peru', 'Yemen', 'Guatemala',
#        'Kansas', 'Australia', 'Wyoming', 'the Kuril Islands', 'Oklahoma',
#        'Tennessee', 'Fiji', 'Pacific-Antarctic Ridge', 'Utah', 'Colombia',
#        'Argentina', 'Oregon', 'Greece', 'Missouri', 'Tajikistan',
#        'Northern Mid-Atlantic Ridge', 'northern Sumatra',
#        'Solomon Islands', 'Burma', 'Taiwan', 'Nicaragua',
#        'South Georgia andSouth Sandwich Islands', 'Idaho', 'Kyrgyzstan',
#        'Arizona', 'Tonga', 'Northern East Pacific Rise', 'South Africa',
#        'Southern Mid-Atlantic Ridge', 'Costa Rica', 'China',
# ...

# %%
zemljotresi.mjesta.value_counts().iloc[:10].plot.barh()
# Out:
# <Axes: ylabel='mjesta'>

# %%
zemljotresi.mjesta.value_counts().iloc[10::-1].plot.barh(figsize=(10,5))
# Out:
# <Axes: ylabel='mjesta'>

# %%
zemljotresi.groupby("mjesta").tsunami.sum().sort_values(ascending=False)
# Out:
# mjesta
# Indonesia                     34
# Papua New Guinea              14
# Alaska                         5
# Russia                         2
# Philippines                    1
#                               ..
# Honduras                       0
# Hawaii                         0
# Haiti                          0
# Guatemala                      0
# the South Sandwich Islands     0
# Name: tsunami, Length: 114, dtype: int64

# %%
pd.pivot_table(zemljotresi, index="mjesta", values="tsunami", aggfunc="sum").sort_values(by="tsunami", ascending=True).reset_index()
# Out:
#                mjesta  tsunami
# 0         Afghanistan        0
# 1             Somalia        0
# 2     Solomon Islands        0
# 3             Socotra        0
# 4        Saint Helena        0
# ..                ...      ...
# 109  Christmas Island        1
# 110            Russia        2
# 111            Alaska        5
# 112  Papua New Guinea       14
# 113         Indonesia       34
#
# [114 rows x 2 columns]

# %%
zemljotresi["tsunami_2"] = zemljotresi.tsunami.astype("bool")
zemljotresi["tsunami_2"]
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9327    False
# 9328    False
# 9329    False
# 9330    False
# 9331    False
# Name: tsunami_2, Length: 9332, dtype: bool

# %%
pivot_tsunami = pd.pivot_table(zemljotresi, index="mjesta", values="tsunami_2", aggfunc="sum")
pivot_tsunami
# Out:
#                              tsunami_2
# mjesta
# Afghanistan                          0
# Alaska                               5
# Argentina                            0
# Arizona                              0
# Arkansas                             0
# ...                                ...
# the Fiji Islands                     0
# the Kermadec Islands                 0
# the Kuril Islands                    0
# the Queen Charlotte Islands          0
# the South Sandwich Islands           0
#
# [114 rows x 1 columns]

# %%
pivot_tsunami
# Out:
#                              tsunami_2
# mjesta
# Afghanistan                          0
# Alaska                               5
# Argentina                            0
# Arizona                              0
# Arkansas                             0
# ...                                ...
# the Fiji Islands                     0
# the Kermadec Islands                 0
# the Kuril Islands                    0
# the Queen Charlotte Islands          0
# the South Sandwich Islands           0
#
# [114 rows x 1 columns]

# %%
pivot_tsunami.sort_values(by="tsunami_2", ascending=False).iloc[0:10]
# Out:
#                   tsunami_2
# mjesta
# Indonesia                34
# Papua New Guinea         14
# Alaska                    5
# Russia                    2
# Philippines               1
# Fiji                      1
# Christmas Island          1
# Mexico                    1
# Califronia                1
# East Timor                1

# %%
pivot_tsunami.sort_values(by="tsunami_2", ascending=False).iloc[10::-1]
# Out:
#                            tsunami_2
# mjesta
# Saint Eustatius and Saba           0
# East Timor                         1
# Califronia                         1
# Mexico                             1
# Christmas Island                   1
# Fiji                               1
# Philippines                        1
# Russia                             2
# Alaska                             5
# Papua New Guinea                  14
# Indonesia                         34

# %%
pivot_tsunami.sort_values(by="tsunami_2", ascending=False).iloc[10::-1].plot.bar(rot=0)
# Out:
# <Axes: xlabel='mjesta'>

# %%
pivot_tsunami.sort_values(by="tsunami_2", ascending=False).iloc[10::-1].plot.bar(rot=90)
# Out:
# <Axes: xlabel='mjesta'>

# %%
pivot_tsunami.sort_values(by="tsunami_2", ascending=False).iloc[10::-1].plot.barh()
# Out:
# <Axes: ylabel='mjesta'>

# %%
ocjene = ocjene_df[["grade"]].copy()
ocjene
# Out:
#       grade
# 0      82.4
# 1      78.2
# 2      79.3
# 3      83.2
# 4      87.4
# ...     ...
# 1995   80.1
# 1996  100.0
# 1997   84.9
# 1998   69.1
# 1999   79.6
#
# [2000 rows x 1 columns]

# %%
ocjene = round(ocjene/10,0)*10
ocjene
# Out:
#       grade
# 0      80.0
# 1      80.0
# 2      80.0
# 3      80.0
# 4      90.0
# ...     ...
# 1995   80.0
# 1996  100.0
# 1997   80.0
# 1998   70.0
# 1999   80.0
#
# [2000 rows x 1 columns]

# %%
ocjene.value_counts().plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
ocjene.value_counts()
# Out:
# grade
# 80.0     712
# 90.0     603
# 70.0     385
# 100.0    228
# 60.0      70
# 30.0       1
# 40.0       1
# Name: count, dtype: int64

# %%
ocjene.value_counts().sample(frac=1).plot.pie()
# Out:
# <Axes: ylabel='count'>

# %%
ocjene.value_counts().reset_index()
# Out:
#    grade  count
# 0   80.0    712
# 1   90.0    603
# 2   70.0    385
# 3  100.0    228
# 4   60.0     70
# 5   30.0      1
# 6   40.0      1

# %%
ocjene.value_counts().sample(frac=1).plot(kind="pie")
# Out:
# <Axes: ylabel='count'>
