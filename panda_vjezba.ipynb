# %%
import pandas as pd

# %%
airbnb_df=pd.read_csv(r"C:\Users\nikap\Downloads\Data\Data\Vjezbe_Primjeri\airbnb_new_york_city_listings.csv")
airbnb_df.head(5)
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
# 2  5121                                    BlissArtsSpace!     7356
# 3  5136           Spacious Brooklyn Duplex, Patio + Garden     7378
# 4  5178                   Large Furnished Room Near B'way　     8967
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75356  -73.98559
# 1  LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.68494  -73.95765
# 2        Garon            Brooklyn  Bedford-Stuyvesant  40.68535  -73.95512
# 3      Rebecca            Brooklyn         Sunset Park  40.66265  -73.99454
# 4     Shunichi           Manhattan             Midtown  40.76457  -73.98317
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36711 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36701 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  object
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df.neighbourhood.unique().shape
# Out:
# (223,)

# %%
airbnb_df.neighbourhood=airbnb_df.neighbourhood.astype('category')
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36711 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36701 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  category
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df.last_review=pd.to_datetime(airbnb_df.last_review)
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36711 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36701 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  category
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df['year']=airbnb_df.last_review.dt.year

# %%
airbnb_df['year']
# Out:
# 0        2019.0
# 1        2021.0
# 2        2016.0
# 3        2014.0
# 4        2021.0
#           ...
# 36719       NaN
# 36720       NaN
# 36721       NaN
# 36722       NaN
# 36723       NaN
# Name: year, Length: 36724, dtype: float64

# %%
airbnb_df.isnull().sum()
# Out:
# id                                   0
# name                                13
# host_id                              0
# host_name                           23
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9415
# reviews_per_month                 9415
# calculated_host_listings_count       0
# availability_365                     0
# year                              9415
# dtype: int64

# %%
airbnb_df.name.fillna("No  name listing", inplace=True)
airbnb_df.name.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 36724 entries, 0 to 36723
# Series name: name
# Non-Null Count  Dtype
# --------------  -----
# 36724 non-null  object
# dtypes: object(1)
# memory usage: 287.0+ KB
# C:\Users\nikap\AppData\Local\Temp\ipykernel_20676\3941928362.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df.name.fillna("No  name listing", inplace=True)

# %%
airbnb_df.isnull().sum()
# Out:
# id                                   0
# name                                 0
# host_id                              0
# host_name                           23
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9415
# reviews_per_month                 9415
# calculated_host_listings_count       0
# availability_365                     0
# year                              9415
# dtype: int64

# %%
airbnb_df.host_name.fillna("J. Doe", inplace=True)
# Out:
# C:\Users\nikap\AppData\Local\Temp\ipykernel_20676\3156200004.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df.host_name.fillna("J. Doe", inplace=True)

# %%
airbnb_df.reviews_per_month.fillna(0.00, inplace=True)
# Out:
# C:\Users\nikap\AppData\Local\Temp\ipykernel_20676\3427412555.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df.reviews_per_month.fillna(0.00, inplace=True)

# %%
airbnb_df.year.fillna(0.00, inplace=True)

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36724 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36724 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  category
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df.year.astype('int16')
# Out:
# 0        2019
# 1        2021
# 2        2016
# 3        2014
# 4        2021
#          ...
# 36719       0
# 36720       0
# 36721       0
# 36722       0
# 36723       0
# Name: year, Length: 36724, dtype: int16

# %%
airbnb_df.last_review.fillna('01-01-1970', inplace=True)

# %%
airbnb_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# year                              0
# dtype: int64

# %%
airbnb_df.name=airbnb_df.name.str.strip()

# %%
podskup_df=pd.DataFrame(airbnb_df[::10])
podskup_df
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 10         7064  Amazing location! Wburg. Large, bright & tranquil      17297
# 20        11943                          Country space in the city      45445
# 30        15220                Best Location in NYC! TIMES SQUARE!      59734
# 40        17037                            Lovely EV Artist's Home      66035
# ...         ...                                                ...        ...
# 36680  51403339                             ECO GLAM APARTMENT UES  415997367
# 36690  51418549                    One Bedroom  -Battery Park City   20761945
# 36700  51427125                                        Waldo Court  228426015
# 36710  51444181               It's a Delightful Day in Bed-Stuy! 2  395798646
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...    2971741
#
# ...

# %%
podskup_df=podskup_df.reset_index(drop=True)

# %%
podskup_df.drop(columns=['index'], inplace=True)

# %%
podskup_df
# Out:
#             id                                               name    host_id  \
# 0         2595                              Skylit Midtown Castle       2845
# 1         7064  Amazing location! Wburg. Large, bright & tranquil      17297
# 2        11943                          Country space in the city      45445
# 3        15220                Best Location in NYC! TIMES SQUARE!      59734
# 4        17037                            Lovely EV Artist's Home      66035
# ...        ...                                                ...        ...
# 3668  51403339                             ECO GLAM APARTMENT UES  415997367
# 3669  51418549                    One Bedroom  -Battery Park City   20761945
# 3670  51427125                                        Waldo Court  228426015
# 3671  51444181               It's a Delightful Day in Bed-Stuy! 2  395798646
# 3672  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...    2971741
#
# ...

# %%
airbnb_df.head(2)
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75356  -73.98559
# 1  LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.68494  -73.95765
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    150              30                 48  2019-11-04
# 1  Entire home/apt     75               1                408  2021-06-29
#
#    reviews_per_month  calculated_host_listings_count  availability_365    year
# 0               0.34                               3               341  2019.0
# 1               5.09                               1               212  2021.0

# %%
airbnb_df.drop(["id","name","host_id","latitude", "longitude"], axis=1, inplace=True)

# %%
airbnb_df["minimum_ravenue"]=airbnb_df["price"]*airbnb_df["minimum_nights"]
airbnb_df
# Out:
#             host_name neighbourhood_group       neighbourhood  \
# 0            Jennifer           Manhattan             Midtown
# 1         LisaRoxanne            Brooklyn  Bedford-Stuyvesant
# 2               Garon            Brooklyn  Bedford-Stuyvesant
# 3             Rebecca            Brooklyn         Sunset Park
# 4            Shunichi           Manhattan             Midtown
# ...               ...                 ...                 ...
# 36719             Asi           Manhattan             Midtown
# 36720      Dina Marie           Manhattan     Upper West Side
# 36721  Stay With Vibe           Manhattan     Upper East Side
# 36722           Chase              Queens             Arverne
# 36723            Nina           Manhattan         Murray Hill
#
#              room_type  price  minimum_nights  number_of_reviews last_review  \
# 0      Entire home/apt    150              30                 48  2019-11-04
# ...

# %%
airbnb_df['neighbourhood_group'].value_counts().sort_values(ascending=False)
# Out:
# neighbourhood_group
# Manhattan        16105
# Brooklyn         14376
# Queens            4902
# Bronx             1026
# Staten Island      315
# Name: count, dtype: int64

# %%
airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36719    False
# 36720    False
# 36721    False
# 36722     True
# 36723    False
# Name: neighbourhood_group, Length: 36724, dtype: bool

# %%
airbnb_df=airbnb_df.drop(["host_name"], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 airbnb_df=airbnb_df.drop(["host_name"], axis=1)
#
# File c:\Users\nikap\anaconda3\envs\my_env_4\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
airbnb_df[airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"])]
# Out:
#       neighbourhood_group    neighbourhood        room_type  price  \
# 0               Manhattan          Midtown  Entire home/apt    150
# 4               Manhattan          Midtown     Private room     61
# 5               Manhattan  Upper West Side     Private room     75
# 8               Manhattan      East Harlem     Private room     65
# 9               Manhattan      East Harlem     Private room     62
# ...                   ...              ...              ...    ...
# 36719           Manhattan          Midtown  Entire home/apt    255
# 36720           Manhattan  Upper West Side  Entire home/apt    306
# 36721           Manhattan  Upper East Side  Entire home/apt     63
# 36722              Queens          Arverne     Private room     75
# 36723           Manhattan      Murray Hill  Entire home/apt    115
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                  30                 48  2019-11-04               0.34
# ...

# %%
airbnb_df[(airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"])) & (airbnb_df["price"]>3000)]
# Out:
#       neighbourhood_group      neighbourhood        room_type  price  \
# 2064            Manhattan    Upper West Side  Entire home/apt   6000
# 2174            Manhattan          Chinatown  Entire home/apt   5250
# 2215            Manhattan       East Village  Entire home/apt   3750
# 3475            Manhattan       East Village     Private room   9990
# 3853            Manhattan        East Harlem  Entire home/apt   9999
# 5153            Manhattan            Chelsea  Entire home/apt   3517
# 7309            Manhattan    Lower East Side     Private room   7314
# 8906            Manhattan            Tribeca  Entire home/apt   5000
# 9282            Manhattan  Greenwich Village  Entire home/apt   6000
# 10395              Queens   Long Island City  Entire home/apt  10000
# 14116              Queens          Briarwood     Private room   9000
# 14268           Manhattan  Greenwich Village  Entire home/apt   3900
# 15760           Manhattan    Upper West Side  Entire home/apt  10000
# ...

# %%
airbnb_df[(airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"])) & (airbnb_df["price"]>6000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 3475 to 27624
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             17 non-null     object
#  1   neighbourhood                   17 non-null     category
#  2   room_type                       17 non-null     object
#  3   price                           17 non-null     int64
#  4   minimum_nights                  17 non-null     int64
#  5   number_of_reviews               17 non-null     int64
#  6   last_review                     17 non-null     datetime64[ns]
#  7   reviews_per_month               17 non-null     float64
#  8   calculated_host_listings_count  17 non-null     int64
#  9   availability_365                17 non-null     int64
#  10  year                            17 non-null     float64
#  11  minimum_ravenue                 17 non-null     int64
# ...

# %%
airbnb_df[(airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"])) | (airbnb_df["price"]>6000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21011 entries, 0 to 36723
# Data columns (total 12 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             21011 non-null  object
#  1   neighbourhood                   21011 non-null  category
#  2   room_type                       21011 non-null  object
#  3   price                           21011 non-null  int64
#  4   minimum_nights                  21011 non-null  int64
#  5   number_of_reviews               21011 non-null  int64
#  6   last_review                     21011 non-null  datetime64[ns]
#  7   reviews_per_month               21011 non-null  float64
#  8   calculated_host_listings_count  21011 non-null  int64
#  9   availability_365                21011 non-null  int64
#  10  year                            21011 non-null  float64
#  11  minimum_ravenue                 21011 non-null  int64
# ...

# %%
airbnb_df.neighbourhood_group.str.contains("Manh").any()
# Out:
# np.True_

# %%
airbnb_df.neighbourhood_group.str.contains("Manh").all()
# Out:
# np.False_

# %%
airbnb_df.neighbourhood_group.str.contains("Manh").all()

# %%
airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"]).any()
# Out:
# np.True_

# %%
airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"]).all()
# Out:
# np.False_

# %%
airbnb_reduced=pd.DataFrame(airbnb_df[airbnb_df['neighbourhood_group'].isin(["Queens","Manhattan"])])

# %%
airbnb_reduced.neighbourhood_group.isin(["Queens","Manhattan"]).all()
# Out:
# np.True_

# %%
# Out:
# <bound method Series.sum of 0        Manhattan
# 4        Manhattan
# 5        Manhattan
# 8        Manhattan
# 9        Manhattan
#            ...
# 36719    Manhattan
# 36720    Manhattan
# 36721    Manhattan
# 36722       Queens
# 36723    Manhattan
# Name: neighbourhood_group, Length: 21007, dtype: object>

# %%
airbnb_df.describe()
# Out:
#               price  minimum_nights  number_of_reviews  \
# count  36724.000000    36724.000000       36724.000000
# mean     160.109057       22.482083          22.854836
# min        0.000000        1.000000           0.000000
# 25%       67.000000        3.000000           0.000000
# 50%      108.000000       30.000000           4.000000
# 75%      175.000000       30.000000          19.000000
# max    10000.000000     1250.000000         998.000000
# std      293.888431       28.361534          49.188479
#
#                          last_review  reviews_per_month  \
# count                          36724       36724.000000
# mean   2007-02-11 08:02:25.082235136           1.022812
# min              1970-01-01 00:00:00           0.000000
# 25%              1970-01-01 00:00:00           0.000000
# 50%              2019-08-31 00:00:00           0.170000
# 75%              2021-05-17 00:00:00           0.990000
# max              2021-08-04 00:00:00         192.930000
# ...

# %%
airbnb_df.describe(include='all')
# Out:
#        neighbourhood_group       neighbourhood        room_type         price  \
# count                36724               36724            36724  36724.000000
# unique                   5                 223                4           NaN
# top              Manhattan  Bedford-Stuyvesant  Entire home/apt           NaN
# freq                 16105                2690            19484           NaN
# mean                   NaN                 NaN              NaN    160.109057
# min                    NaN                 NaN              NaN      0.000000
# 25%                    NaN                 NaN              NaN     67.000000
# 50%                    NaN                 NaN              NaN    108.000000
# 75%                    NaN                 NaN              NaN    175.000000
# max                    NaN                 NaN              NaN  10000.000000
# std                    NaN                 NaN              NaN    293.888431
#
# ...

# %%
statistika_airbnb=airbnb_df.describe(include='all')

# %%
statistika_airbnb.loc['std'].dropna().sort_values(ascending=False).reset_index().iloc[0]
# Out:
# index    minimum_ravenue
# std         13745.108195
# Name: 0, dtype: object

# %%
airbnb_df.corr(numeric_only=True).abs()
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.004452           0.030849
# minimum_nights                  0.004452        1.000000           0.143130
# number_of_reviews               0.030849        0.143130           1.000000
# reviews_per_month               0.011955        0.151884           0.359701
# calculated_host_listings_count  0.000460        0.059466           0.102862
# availability_365                0.069875        0.020994           0.104905
# year                            0.053948        0.128863           0.273289
# minimum_ravenue                 0.623080        0.376846           0.053733
#
#                                 reviews_per_month  \
# price                                    0.011955
# minimum_nights                           0.151884
# number_of_reviews                        0.359701
# reviews_per_month                        1.000000
# ...

# %%
corr_df=airbnb_df.corr(numeric_only=True).abs()

# %%
corr_df.minimum_ravenue
# Out:
# price                             0.623080
# minimum_nights                    0.376846
# number_of_reviews                 0.053733
# reviews_per_month                 0.051499
# calculated_host_listings_count    0.016462
# availability_365                  0.034378
# year                              0.072852
# minimum_ravenue                   1.000000
# Name: minimum_ravenue, dtype: float64

# %%
corr_df.minimum_ravenue.drop(['minimum_ravenue'])
# Out:
# price                             0.623080
# minimum_nights                    0.376846
# number_of_reviews                 0.053733
# reviews_per_month                 0.051499
# calculated_host_listings_count    0.016462
# availability_365                  0.034378
# year                              0.072852
# Name: minimum_ravenue, dtype: float64

# %%
corr_df['minimum_ravenue'].drop(['minimum_ravenue'])
# Out:
# price                             0.623080
# minimum_nights                    0.376846
# number_of_reviews                 0.053733
# reviews_per_month                 0.051499
# calculated_host_listings_count    0.016462
# availability_365                  0.034378
# year                              0.072852
# Name: minimum_ravenue, dtype: float64

# %%
corr_df['minimum_ravenue'].drop(['minimum_ravenue']).max()
# Out:
# 0.6230799400103795

# %%
corr_df['minimum_ravenue'].drop(['minimum_ravenue']).min()
# Out:
# 0.016462452511241798

# %%
corr_df['minimum_ravenue'].drop(['minimum_ravenue']).idxmax()
# Out:
# 'price'

# %%
corr_df['minimum_ravenue'][corr_df['minimum_ravenue']==corr_df['minimum_ravenue'].drop(['minimum_ravenue']).max()]
# Out:
# price    0.62308
# Name: minimum_ravenue, dtype: float64

# %%
airbnb_df.describe(include='all').loc['mean'].dropna()
# Out:
# price                                                160.109057
# minimum_nights                                        22.482083
# number_of_reviews                                     22.854836
# last_review                       2007-02-11 08:02:25.082235136
# reviews_per_month                                      1.022812
# calculated_host_listings_count                        13.432306
# availability_365                                     122.570608
# year                                                1501.684049
# minimum_ravenue                                     3562.474268
# Name: mean, dtype: object

# %%
airbnb_df.describe(include='all').loc['mean'].dropna()
# Out:
# price                                                160.109057
# minimum_nights                                        22.482083
# number_of_reviews                                     22.854836
# last_review                       2007-02-11 08:02:25.082235136
# reviews_per_month                                      1.022812
# calculated_host_listings_count                        13.432306
# availability_365                                     122.570608
# year                                                1501.684049
# minimum_ravenue                                     3562.474268
# Name: mean, dtype: object

# %%
type(airbnb_df.describe(include='all').loc['mean'].dropna())
# Out:
# pandas.core.series.Series

# %%
airbnb_df.describe(include='all').loc['mean'].dropna().drop(['last_review']).min()
# Out:
# np.float64(1.0228120575100752)

# %%
airbnb_df.describe(include='all').loc['mean'].dropna().drop(['last_review']).idxmin()
# Out:
# 'reviews_per_month'

# %%
testcorr=airbnb_df.corr(numeric_only=True)[airbnb_df.describe(include='all').loc['mean'].dropna().drop(['last_review']).idxmin()].abs()
testcorr
# Out:
# price                             0.011955
# minimum_nights                    0.151884
# number_of_reviews                 0.359701
# reviews_per_month                 1.000000
# calculated_host_listings_count    0.043260
# availability_365                  0.085797
# year                              0.178436
# minimum_ravenue                   0.051499
# Name: reviews_per_month, dtype: float64

# %%
type(testcorr)
# Out:
# pandas.core.series.Series

# %%
testcorr.drop([airbnb_df.describe(include='all').loc['mean'].dropna().drop(['last_review']).idxmin()], inplace=True)
testcorr
# Out:
# price                             0.011955
# minimum_nights                    0.151884
# number_of_reviews                 0.359701
# calculated_host_listings_count    0.043260
# availability_365                  0.085797
# year                              0.178436
# minimum_ravenue                   0.051499
# Name: reviews_per_month, dtype: float64

# %%
testcorr.idxmax()
# Out:
# 'number_of_reviews'

# %%
corr_df['minimum_ravenue'].drop(['minimum_ravenue']).idxmax()
# Out:
# 'price'

# %%
airbnb_df[["room_type","price","minimum_ravenue"]].groupby("room_type").mean()
# Out:
#                       price  minimum_ravenue
# room_type
# Entire home/apt  213.324779      4949.334480
# Hotel room       293.262548      2662.552124
# Private room      96.617690      1963.337077
# Shared room      107.978297      2575.096828

# %%
airbnb_df[["room_type","price","minimum_ravenue"]].groupby("room_type").min()
# Out:
#                  price  minimum_ravenue
# room_type
# Entire home/apt     10               29
# Hotel room           0                0
# Private room        10               18
# Shared room         15               15

# %%
airbnb_df[["room_type","price","minimum_ravenue"]].groupby("room_type").std()
# Out:
#                       price  minimum_ravenue
# room_type
# Entire home/apt  310.830582     15674.139091
# Hotel room       279.581360      6290.617826
# Private room     249.534072     10731.841625
# Shared room      451.337586     17079.169710

# %%
airbnb_df[["room_type","price","minimum_ravenue"]].groupby("room_type").std().reset_index()
# Out:
#          room_type       price  minimum_ravenue
# 0  Entire home/apt  310.830582     15674.139091
# 1       Hotel room  279.581360      6290.617826
# 2     Private room  249.534072     10731.841625
# 3      Shared room  451.337586     17079.169710

# %%
airbnb_df[["room_type","price","minimum_ravenue"]].groupby("room_type", as_index=False).std()
# Out:
#          room_type       price  minimum_ravenue
# 0  Entire home/apt  310.830582     15674.139091
# 1       Hotel room  279.581360      6290.617826
# 2     Private room  249.534072     10731.841625
# 3      Shared room  451.337586     17079.169710

# %%
airbnb_df[["room_type","price","minimum_ravenue", "minimum_nights"]].groupby(["room_type", "minimum_nights"], as_index=False).std()
# Out:
#            room_type  minimum_nights       price  minimum_ravenue
# 0    Entire home/apt               1  467.872986       467.872986
# 1    Entire home/apt               2  155.620042       311.240083
# 2    Entire home/apt               3  262.858725       788.576176
# 3    Entire home/apt               4  213.422317       853.689269
# 4    Entire home/apt               5  212.349490      1061.747452
# ..               ...             ...         ...              ...
# 211      Shared room              75         NaN              NaN
# 212      Shared room             100   52.325902      5232.590181
# 213      Shared room             120         NaN              NaN
# 214      Shared room             180  114.551299     20619.233739
# 215      Shared room             999         NaN              NaN
#
# [216 rows x 4 columns]

# %%
moj_x={"x": [10,50,80,110,140,-10,-50,80,90,110]}
moj_x_df=pd.DataFrame(moj_x)
moj_x_df
# Out:
#      x
# 0   10
# 1   50
# 2   80
# 3  110
# 4  140
# 5  -10
# 6  -50
# 7   80
# 8   90
# 9  110

# %%
import numpy as np

moj_x_df["-x"]=moj_x_df["x"]*-1
moj_x_df["-x+5"]=moj_x_df["x"]*-1+np.random.randint(low=10, high=20, size=len(moj_x_df["x"]))

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(moj_x_df[["x","-x","-x+5"]], figsize=(15,8))
# Out:
# array([[<Axes: xlabel='x', ylabel='x'>, <Axes: xlabel='-x', ylabel='x'>,
#         <Axes: xlabel='-x+5', ylabel='x'>],
#        [<Axes: xlabel='x', ylabel='-x'>,
#         <Axes: xlabel='-x', ylabel='-x'>,
#         <Axes: xlabel='-x+5', ylabel='-x'>],
#        [<Axes: xlabel='x', ylabel='-x+5'>,
#         <Axes: xlabel='-x', ylabel='-x+5'>,
#         <Axes: xlabel='-x+5', ylabel='-x+5'>]], dtype=object)

# %%
moj_x_df[["x","-x","-x+5"]].corr(numeric_only=True)
# Out:
#              x        -x      -x+5
# x     1.000000 -1.000000 -0.998852
# -x   -1.000000  1.000000  0.998852
# -x+5 -0.998852  0.998852  1.000000

# %%
from pandas.plotting import autocorrelation_plot

# %%
kupci_df=pd.read_csv(r'C:\Users\nikap\Downloads\Data\Data\Vjezbe_Primjeri\mall_customers.csv')

# %%
autocorrelation_plot(kupci_df.Age)
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
kupci_df.head(2)
# Out:
#    CustomerID Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1   Male   19                  15                      39
# 1           2   Male   21                  15                      81

# %%
autocorrelation_plot(kupci_df["Spending Score (1-100)"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
kupci_df.corr(numeric_only=True)
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
autocorrelation_plot(kupci_df["Age"])
autocorrelation_plot(kupci_df["Spending Score (1-100)"])
autocorrelation_plot(kupci_df["Annual Income (k$)"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
pd.pivot_table(airbnb_df, values=["price"], index=["room_type"], columns=["year"], aggfunc="median")
# Out:
#                  price                                                   \
# year            0.0    2010.0 2011.0 2012.0 2013.0 2014.0 2015.0 2016.0
# room_type
# Entire home/apt  180.0  228.0  165.0  150.0  150.0  170.0  150.0  150.0
# Hotel room       370.0    NaN    NaN    NaN    NaN    NaN    NaN  349.0
# Private room      68.0    NaN  349.0   90.0  100.0   80.0   75.0   65.0
# Shared room       65.0    NaN    NaN    NaN   50.0   82.0   61.5   95.0
#
#
# year            2017.0 2018.0 2019.0 2020.0 2021.0
# room_type
# Entire home/apt  149.0  150.0  150.0  148.0  150.0
# Hotel room       248.0  125.0  291.0  211.5  165.0
# Private room      65.0   65.0   69.0   63.0   68.0
# Shared room       51.0   57.0   55.0   45.0   40.0

# %%
pd.pivot_table(airbnb_df, values=["price"], index=["room_type"], columns=["year"], aggfunc="mean")
# Out:
#                       price                                               \
# year                 0.0    2010.0 2011.0 2012.0      2013.0      2014.0
# room_type
# Entire home/apt  262.485149  228.0  191.8  156.0  170.666667  184.879032
# Hotel room       407.655738    NaN    NaN    NaN         NaN         NaN
# Private room     113.444228    NaN  349.0  112.9  102.454545   95.848485
# Shared room      104.267760    NaN    NaN    NaN   50.000000   82.000000
#
#                                                                              \
# year                 2015.0      2016.0      2017.0      2018.0      2019.0
# room_type
# Entire home/apt  228.021739  187.533696  205.882831  178.282708  197.652335
# Hotel room              NaN  349.000000  241.000000  128.333333  291.718750
# Private room      83.240449  104.994702   78.045455   82.330695   83.535901
# Shared room      166.300000  117.058824   67.700000  107.535714  239.241379
#
#
# year                 2020.0      2021.0
# ...

# %%
airbnb_df[(airbnb_df["room_type"]=="Private room") & (airbnb_df["year"]==2014)].price.mean()
# Out:
# np.float64(95.84848484848484)

# %%
ocjene=pd.read_csv(r'C:\Users\nikap\Downloads\Data\Data\Vjezbe_Primjeri\ocjene.csv')
ocjene.head(2)
# Out:
#     fname     lname  gender  age  exercise  hours  grade  \
# 0  Marcia      Pugh  female   17         3     10   82.4
# 1  Kadeem  Morrison    male   18         4      4   78.2
#
#                                    address
# 0  9253 Richardson Road, Matawan, NJ 07747
# 1         33 Spring Dr., Taunton, MA 02780

# %%
pd.pivot_table(ocjene, index=["gender"], values=["age", "hours", "grade", "exercise"], aggfunc="mean")
# Out:
#            age  exercise    grade   hours
# gender
# female  16.568     3.047  82.7173  10.932
# male    16.589     2.954  82.3948  11.045

# %%
pd.pivot_table(airbnb_df, index=["room_type"], values=["price", "minimum_ravenue"], aggfunc="mean", margins=True)
# Out:
#                  minimum_ravenue       price
# room_type
# Entire home/apt      4949.334480  213.324779
# Hotel room           2662.552124  293.262548
# Private room         1963.337077   96.617690
# Shared room          2575.096828  107.978297
# All                  3562.474268  160.109057

# %%
voce_podaci={
    "Ime":["Jabuka", "Banana", "Narandža","Jagoda","Grođže","Jabuka", "Banana","Jabuka", "Banana"],
    "Boja":["Crvena","Žuta", "Narancasta","Crvena", "Zelena","Zelena","Žuta","Crvena", "Žuta"],
    "Težina (g)":[150,120,180,15,5,1200,200,300, 500],
    "Cijena po kg (EUR)": [2,1,4,10,20,19,8,9,5]
}

df=pd.DataFrame(voce_podaci)
df
# Out:
#         Ime        Boja  Težina (g)  Cijena po kg (EUR)
# 0    Jabuka      Crvena         150                   2
# 1    Banana        Žuta         120                   1
# 2  Narandža  Narancasta         180                   4
# 3    Jagoda      Crvena          15                  10
# 4    Grođže      Zelena           5                  20
# 5    Jabuka      Zelena        1200                  19
# 6    Banana        Žuta         200                   8
# 7    Jabuka      Crvena         300                   9
# 8    Banana        Žuta         500                   5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Ime                 9 non-null      object
#  1   Boja                9 non-null      object
#  2   Težina (g)          9 non-null      int64
#  3   Cijena po kg (EUR)  9 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 420.0+ bytes

# %%
pd.pivot_table(df, index="Ime", values=["Težina (g)", "Cijena po kg (EUR)"], aggfunc={"Težina (g)":"sum", "Cijena po kg (EUR)":"mean"})
# Out:
#           Cijena po kg (EUR)  Težina (g)
# Ime
# Banana              4.666667         820
# Grođže             20.000000           5
# Jabuka             10.000000        1650
# Jagoda             10.000000          15
# Narandža            4.000000         180

# %%
pd.pivot_table(df, index=["Ime","Boja"], values=["Težina (g)", "Cijena po kg (EUR)"], aggfunc={"Težina (g)":"sum", "Cijena po kg (EUR)":"mean"})
# Out:
#                      Cijena po kg (EUR)  Težina (g)
# Ime      Boja
# Banana   Žuta                  4.666667         820
# Grođže   Zelena               20.000000           5
# Jabuka   Crvena                5.500000         450
#          Zelena               19.000000        1200
# Jagoda   Crvena               10.000000          15
# Narandža Narancasta            4.000000         180
