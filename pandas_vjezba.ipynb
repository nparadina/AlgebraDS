# %%
import pandas as pd

# %%
polaznici = {
    "Ime": ["Pero", "Ivana", "Josip"],
    "Prezime": ["Peric", "Ivanic", "Novak"],
    "Bodovi": [2, 80, 64]
    
}

polaznici
# Out:
# {'Ime': ['Pero', 'Ivana', 'Josip'],
#  'Prezime': ['Peric', 'Ivanic', 'Novak'],
#  'Bodovi': [2, 80, 64]}

# %%
data_frame = pd.DataFrame(polaznici)
data_frame
# Out:
#      Ime Prezime  Bodovi
# 0   Pero   Peric       2
# 1  Ivana  Ivanic      80
# 2  Josip   Novak      64

# %%
type(data_frame)
# Out:
# pandas.core.frame.DataFrame

# %%
stupac = data_frame["Prezime"]
stupac
# Out:
# 0     Peric
# 1    Ivanic
# 2     Novak
# Name: Prezime, dtype: object

# %%
type(stupac)
# Out:
# pandas.core.series.Series

# %%
stupac.values
# Out:
# array(['Peric', 'Ivanic', 'Novak'], dtype=object)

# %%
type(stupac.values)
# Out:
# numpy.ndarray

# %%
stupac.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
stupac
# Out:
# 0     Peric
# 1    Ivanic
# 2     Novak
# Name: Prezime, dtype: object

# %%
stupac[1]
# Out:
# 'Ivanic'

# %%
data_frame["Prezime"]
# Out:
# 0     Peric
# 1    Ivanic
# 2     Novak
# Name: Prezime, dtype: object

# %%
data_frame.Prezime
# Out:
# 0     Peric
# 1    Ivanic
# 2     Novak
# Name: Prezime, dtype: object

# %%
serija = pd.Series(["Marko", "Ana", "Lucija"], index = ["Prvi", "Drugi", "Treci"])
serija
# Out:
# Prvi      Marko
# Drugi       Ana
# Treci    Lucija
# dtype: object

# %%
# serija = pd.Series(["Marko", "Ana", "Lucija"], index = ["Prvi", "Drugi", "Treci", "xyz"])

# %%
stupac[1]
# Out:
# 'Ivanic'

# %%
serija[1]
# Out:
# C:\Users\brankor\AppData\Local\Temp\ipykernel_25628\4245468551.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   serija[1]
# 'Ana'

# %%
serija
# Out:
# Prvi      Marko
# Drugi       Ana
# Treci    Lucija
# dtype: object

# %%
serija_kopija =pd.Series(serija, index =["Drugi", "Treci"])
serija_kopija
# Out:
# Drugi       Ana
# Treci    Lucija
# dtype: object

# %%
serija_kopija["Treci"] = "Ana-Marija"

# %%
serija_kopija
# Out:
# Drugi           Ana
# Treci    Ana-Marija
# dtype: object

# %%
serija
# Out:
# Prvi      Marko
# Drugi       Ana
# Treci    Lucija
# dtype: object

# %%
serija[1:]
# Out:
# Drugi       Ana
# Treci    Lucija
# dtype: object

# %%
serija_naivna_kopija = serija[1:]

# %%
serija_naivna_kopija
# Out:
# Drugi       Ana
# Treci    Lucija
# dtype: object

# %%
serija_naivna_kopija["Treci"] = "Zdravko"

# %%
serija_naivna_kopija
# Out:
# Drugi        Ana
# Treci    Zdravko
# dtype: object

# %%
serija
# Out:
# Prvi       Marko
# Drugi        Ana
# Treci    Zdravko
# dtype: object

# %%
serija_kopija
# Out:
# Drugi           Ana
# Treci    Ana-Marija
# dtype: object

# %%
data_frame
# Out:
#      Ime Prezime  Bodovi
# 0   Pero   Peric       2
# 1  Ivana  Ivanic      80
# 2  Josip   Novak      64

# %%
# data_frame[0]

# %%
data_frame.loc[0]
# Out:
# Ime         Pero
# Prezime    Peric
# Bodovi         2
# Name: 0, dtype: object

# %%
data_frame.loc[0, :]
# Out:
# Ime         Pero
# Prezime    Peric
# Bodovi         2
# Name: 0, dtype: object

# %%
data_frame.iloc[0]
# Out:
# Ime         Pero
# Prezime    Peric
# Bodovi         2
# Name: 0, dtype: object

# %%
data_frame
# Out:
#      Ime Prezime  Bodovi
# 0   Pero   Peric       2
# 1  Ivana  Ivanic      80
# 2  Josip   Novak      64

# %%
data_frame.loc[:, "Ime"]
# Out:
# 0     Pero
# 1    Ivana
# 2    Josip
# Name: Ime, dtype: object

# %%
type(data_frame.loc[:, "Ime"])
# Out:
# pandas.core.series.Series

# %%
data_frame.loc[:, ["Ime"]]
# Out:
#      Ime
# 0   Pero
# 1  Ivana
# 2  Josip

# %%
type(data_frame.loc[:, ["Ime"]])
# Out:
# pandas.core.frame.DataFrame

# %%
data_frame.Ime
# Out:
# 0     Pero
# 1    Ivana
# 2    Josip
# Name: Ime, dtype: object

# %%
data_frame["Ime"]
# Out:
# 0     Pero
# 1    Ivana
# 2    Josip
# Name: Ime, dtype: object

# %%
data_frame.loc[:, ["Ime", "Prezime"]]
# Out:
#      Ime Prezime
# 0   Pero   Peric
# 1  Ivana  Ivanic
# 2  Josip   Novak

# %%
data_frame.iloc[:, [1, 2]]
# Out:
#   Prezime  Bodovi
# 0   Peric       2
# 1  Ivanic      80
# 2   Novak      64

# %%
data_frame.iloc[[0, 1], [1, 2]]
# Out:
#   Prezime  Bodovi
# 0   Peric       2
# 1  Ivanic      80

# %%
data_frame.loc[[0, 1], ["Prezime", "Bodovi"]]
# Out:
#   Prezime  Bodovi
# 0   Peric       2
# 1  Ivanic      80

# %%
data_frame
# Out:
#      Ime Prezime  Bodovi
# 0   Pero   Peric       2
# 1  Ivana  Ivanic      80
# 2  Josip   Novak      64

# %%
polaznici_df = pd.DataFrame(polaznici, index=["Prvi", "Drugi", "Treci"])
polaznici_df
# Out:
#          Ime Prezime  Bodovi
# Prvi    Pero   Peric       2
# Drugi  Ivana  Ivanic      80
# Treci  Josip   Novak      64

# %%
polaznici_df.index.values
# Out:
# array(['Prvi', 'Drugi', 'Treci'], dtype=object)

# %%
polaznici_df.loc[["Prvi", "Treci"]]
# Out:
#          Ime Prezime  Bodovi
# Prvi    Pero   Peric       2
# Treci  Josip   Novak      64

# %%
polaznici_df.loc[:, ["Ime", "Prezime"]]
# Out:
#          Ime Prezime
# Prvi    Pero   Peric
# Drugi  Ivana  Ivanic
# Treci  Josip   Novak

# %%
polaznici_df.iloc[:, [1, 2]]
# Out:
#       Prezime  Bodovi
# Prvi    Peric       2
# Drugi  Ivanic      80
# Treci   Novak      64

# %%
polaznici_df.iloc[[0, 1], [1, 2]]
# Out:
#       Prezime  Bodovi
# Prvi    Peric       2
# Drugi  Ivanic      80

# %%
# polaznici_df.loc[[0, 1], ["Prezime", "Bodovi"]]

# %%
polaznici_df.loc[["Prvi", "Drugi"], ["Prezime", "Bodovi"]]
# Out:
#       Prezime  Bodovi
# Prvi    Peric       2
# Drugi  Ivanic      80

# %%
polaznici_df_3 = pd.DataFrame(polaznici, index=[5, 99, 99])
polaznici_df_3
# Out:
#       Ime Prezime  Bodovi
# 5    Pero   Peric       2
# 99  Ivana  Ivanic      80
# 99  Josip   Novak      64

# %%
polaznici_df_3.loc[[99]]
# Out:
#       Ime Prezime  Bodovi
# 99  Ivana  Ivanic      80
# 99  Josip   Novak      64

# %%
polaznici_df_3.iloc[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[156], line 1
# ----> 1 polaznici_df_3.iloc[5]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# ...

# %%
polaznici_df_2 = pd.DataFrame(polaznici, index=[5, 9, 99])
polaznici_df_2
# Out:
#       Ime Prezime  Bodovi
# 5    Pero   Peric       2
# 9   Ivana  Ivanic      80
# 99  Josip   Novak      64

# %%
polaznici_df_2.iloc[[0, 2]]
# Out:
#       Ime Prezime  Bodovi
# 5    Pero   Peric       2
# 99  Josip   Novak      64

# %%
polaznici_df_2.loc[[5, 99]]
# Out:
#       Ime Prezime  Bodovi
# 5    Pero   Peric       2
# 99  Josip   Novak      64

# %%
polaznici_2 = {
    "bodovi": [2, 80, 64],
    "prezime": ["Peric", "Ivanic", "Novak"],
    "ime": ["Pero", "Ivana", "Josip"],
    
    
}

# %%
polaznici_2_df = pd.DataFrame(polaznici_2)

# %%
polaznici_2_df
# Out:
#    bodovi prezime    ime
# 0       2   Peric   Pero
# 1      80  Ivanic  Ivana
# 2      64   Novak  Josip

# %%
data_frame.Ime
# Out:
# 0     Pero
# 1    Ivana
# 2    Josip
# Name: Ime, dtype: object

# %%
polaznici_2_df.ime
# Out:
# 0     Pero
# 1    Ivana
# 2    Josip
# Name: ime, dtype: object

# %%
temperatura_gradovi = pd.DataFrame({
    'Grad': ['Zagreb', 'Cakovec', 'Varazdin', 'Split', 'Novigrad', 'Knin', 'Zadar', 'Pozega', 'Rijeka'],
    'Temperatura': [23, 24.5, 22, 18, 32, 21, 19.2, 22.4, 31.2],
})
temperatura_gradovi
# Out:
#        Grad  Temperatura
# 0    Zagreb         23.0
# 1   Cakovec         24.5
# 2  Varazdin         22.0
# 3     Split         18.0
# 4  Novigrad         32.0
# 5      Knin         21.0
# 6     Zadar         19.2
# 7    Pozega         22.4
# 8    Rijeka         31.2

# %%
temperatura_gradovi.head()
# Out:
#        Grad  Temperatura
# 0    Zagreb         23.0
# 1   Cakovec         24.5
# 2  Varazdin         22.0
# 3     Split         18.0
# 4  Novigrad         32.0

# %%
temperatura_gradovi.head(2)
# Out:
#       Grad  Temperatura
# 0   Zagreb         23.0
# 1  Cakovec         24.5

# %%
temperatura_gradovi.tail(2)
# Out:
#      Grad  Temperatura
# 7  Pozega         22.4
# 8  Rijeka         31.2

# %%
temperatura_gradovi.tail()
# Out:
#        Grad  Temperatura
# 4  Novigrad         32.0
# 5      Knin         21.0
# 6     Zadar         19.2
# 7    Pozega         22.4
# 8    Rijeka         31.2

# %%
def funkcija(param1, param2):
    pass

# %%
funkcija(1, 7)

# %%
funkcija("Ime", "Prezime")

# %%
funkcija(["Ime"], ["Prezime"])

# %%
ocjene = pd.read_csv("ocjene.csv")
ocjene
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
ocjene_2 = pd.read_csv("ocjene_2.csv")
ocjene_2
# Out:
#      fname;lname;gender;age;exercise;hours;grade;address
# 0     Marcia;Pugh;female;17;3;10;82.4;"9253 Richards...
# 1     Kadeem;Morrison;male;18;4;4;78.2;"33 Spring Dr...
# 2     Nash;Powell;male;18;5;9;79.3;"41 Hill Avenue; ...
# 3     Noelani;Wagner;female;14;2;7;83.2;"8839 Marsha...
# 4     Noelani;Cherry;female;18;4;15;87.4;"8304 Charl...
# ...                                                 ...
# 1995  Cody;Shepherd;male;19;1;8;80.1;"982 West Stree...
# 1996  Geraldine;Peterson;female;16;4;18;100.0;"78 Mo...
# 1997  Mercedes;Leon;female;18;3;14;84.9;"30 Glenridg...
# 1998  Lucius;Rowland;male;16;1;7;69.1;"342 West Mead...
# 1999  Linus;Morris;male;19;4;10;79.6;"81 Homestead D...
#
# [2000 rows x 1 columns]

# %%
ocjene_2 = pd.read_csv("ocjene_2.csv", sep=";")
ocjene_2
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road; Matawan; NJ 07747
# 1                33 Spring Dr.; Taunton; MA 02780
# 2                41 Hill Avenue; Mentor; OH 44060
# ...

# %%
ocjene_3 = pd.read_csv("ocjene_2 copy.csv", sep=";")
ocjene_3
# Out:
#                      fname  lname  gender  age  exercise  \
# Marcia    Pugh      female     17       3   10      82.4
# Kadeem    Morrison    male     18       4    4      78.2
# Nash      Powell      male     18       5    9      79.3
# Noelani   Wagner    female     14       2    7      83.2
#           Cherry    female     18       4   15      87.4
# ...                    ...    ...     ...  ...       ...
# Cody      Shepherd    male     19       1    8      80.1
# Geraldine Peterson  female     16       4   18     100.0
# Mercedes  Leon      female     18       3   14      84.9
# Lucius    Rowland     male     16       1    7      69.1
# Linus     Morris      male     19       4   10      79.6
#
#                                          hours            grade     address
# Marcia    Pugh           '9253 Richardson Road          Matawan   NJ 07747'
# Kadeem    Morrison              '33 Spring Dr.          Taunton   MA 02780'
# ...

# %%
help(pd.read_csv)
# Out:
# Help on function read_csv in module pandas.io.parsers.readers:
#
# ...

# %%
ocjene_subset_df = pd.read_csv("ocjene.csv", usecols=["fname", "lname", "grade"])
ocjene_subset_df
# Out:
#           fname     lname  grade
# 0        Marcia      Pugh   82.4
# 1        Kadeem  Morrison   78.2
# 2          Nash    Powell   79.3
# 3       Noelani    Wagner   83.2
# 4       Noelani    Cherry   87.4
# ...         ...       ...    ...
# 1995       Cody  Shepherd   80.1
# 1996  Geraldine  Peterson  100.0
# 1997   Mercedes      Leon   84.9
# 1998     Lucius   Rowland   69.1
# 1999      Linus    Morris   79.6
#
# [2000 rows x 3 columns]

# %%
ocjene_subset_df.head()
# Out:
#      fname     lname  grade
# 0   Marcia      Pugh   82.4
# 1   Kadeem  Morrison   78.2
# 2     Nash    Powell   79.3
# 3  Noelani    Wagner   83.2
# 4  Noelani    Cherry   87.4

# %%
ocjene_subset_df.tail()
# Out:
#           fname     lname  grade
# 1995       Cody  Shepherd   80.1
# 1996  Geraldine  Peterson  100.0
# 1997   Mercedes      Leon   84.9
# 1998     Lucius   Rowland   69.1
# 1999      Linus    Morris   79.6

# %%
ocjene.to_json("nove_ocjene.json")

# %%
pd.read_json("nove_ocjene.json")
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 0        Marcia      Pugh  female   17         3     10   82.4
# 1        Kadeem  Morrison    male   18         4      4   78.2
# 2          Nash    Powell    male   18         5      9   79.3
# 3       Noelani    Wagner  female   14         2      7   83.2
# 4       Noelani    Cherry  female   18         4     15   87.4
# ...         ...       ...     ...  ...       ...    ...    ...
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# 1                33 Spring Dr., Taunton, MA 02780
# 2                41 Hill Avenue, Mentor, OH 44060
# ...

# %%
import sqlite3

# %%
konekcija = sqlite3.connect("ocjene.db")

ocjene.to_sql(name="ocjene", con=konekcija)

konekcija.commit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[185], line 3
#       1 konekcija = sqlite3.connect("ocjene.db")
# ----> 3 ocjene.to_sql(name="ocjene", con=konekcija)
#       5 konekcija.commit()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
# ...

# %%
sql_df = pd.read_sql("SELECT * FROM ocjene", konekcija)
sql_df
# Out:
#       index      fname     lname  gender  age  exercise  hours  grade  \
# 0         0     Marcia      Pugh  female   17         3     10   82.4
# 1         1     Kadeem  Morrison    male   18         4      4   78.2
# 2         2       Nash    Powell    male   18         5      9   79.3
# 3         3    Noelani    Wagner  female   14         2      7   83.2
# 4         4    Noelani    Cherry  female   18         4     15   87.4
# ...     ...        ...       ...     ...  ...       ...    ...    ...
# 1995   1995       Cody  Shepherd    male   19         1      8   80.1
# 1996   1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   1997   Mercedes      Leon  female   18         3     14   84.9
# 1998   1998     Lucius   Rowland    male   16         1      7   69.1
# 1999   1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 0         9253 Richardson Road, Matawan, NJ 07747
# ...

# %%
konekcija.close()

# %%
automobili = pd.read_csv("cars.csv")
automobili
# Out:
#     Car;MPG;Cylinders;Displacement;Horsepower;Weight;Acceleration;Model;Origin
# 0    STRING;DOUBLE;INT;DOUBLE;DOUBLE;DOUBLE;DOUBLE;...
# 1    Chevrolet Chevelle Malibu;18.0;8;307.0;130.0;3...
# 2    Buick Skylark 320;15.0;8;350.0;165.0;3693.;11....
# 3    Plymouth Satellite;18.0;8;318.0;150.0;3436.;11...
# 4    AMC Rebel SST;16.0;8;304.0;150.0;3433.;12.0;70;US
# ..                                                 ...
# 402  Ford Mustang GL;27.0;4;140.0;86.00;2790.;15.6;...
# 403  Volkswagen Pickup;44.0;4;97.00;52.00;2130.;24....
# 404  Dodge Rampage;32.0;4;135.0;84.00;2295.;11.6;82;US
# 405    Ford Ranger;28.0;4;120.0;79.00;2625.;18.6;82;US
# 406     Chevy S-10;31.0;4;119.0;82.00;2720.;19.4;82;US
#
# [407 rows x 1 columns]

# %%
automobili = pd.read_csv("cars.csv", sep=";")
automobili
# Out:
#                            Car     MPG Cylinders Displacement Horsepower  \
# 0                       STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1    Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2            Buick Skylark 320    15.0         8        350.0      165.0
# 3           Plymouth Satellite    18.0         8        318.0      150.0
# 4                AMC Rebel SST    16.0         8        304.0      150.0
# ..                         ...     ...       ...          ...        ...
# 402            Ford Mustang GL    27.0         4        140.0      86.00
# 403          Volkswagen Pickup    44.0         4        97.00      52.00
# 404              Dodge Rampage    32.0         4        135.0      84.00
# 405                Ford Ranger    28.0         4        120.0      79.00
# 406                 Chevy S-10    31.0         4        119.0      82.00
#
#      Weight Acceleration Model  Origin
# 0    DOUBLE       DOUBLE   INT     CAT
# ...

# %%
automobili.head()
# Out:
#                          Car     MPG Cylinders Displacement Horsepower  \
# 0                     STRING  DOUBLE       INT       DOUBLE     DOUBLE
# 1  Chevrolet Chevelle Malibu    18.0         8        307.0      130.0
# 2          Buick Skylark 320    15.0         8        350.0      165.0
# 3         Plymouth Satellite    18.0         8        318.0      150.0
# 4              AMC Rebel SST    16.0         8        304.0      150.0
#
#    Weight Acceleration Model Origin
# 0  DOUBLE       DOUBLE   INT    CAT
# 1   3504.         12.0    70     US
# 2   3693.         11.5    70     US
# 3   3436.         11.0    70     US
# 4   3433.         12.0    70     US

# %%
automobili = automobili.drop([0])
automobili
# Out:
#                            Car   MPG Cylinders Displacement Horsepower Weight  \
# 1    Chevrolet Chevelle Malibu  18.0         8        307.0      130.0  3504.
# 2            Buick Skylark 320  15.0         8        350.0      165.0  3693.
# 3           Plymouth Satellite  18.0         8        318.0      150.0  3436.
# 4                AMC Rebel SST  16.0         8        304.0      150.0  3433.
# 5                  Ford Torino  17.0         8        302.0      140.0  3449.
# ..                         ...   ...       ...          ...        ...    ...
# 402            Ford Mustang GL  27.0         4        140.0      86.00  2790.
# 403          Volkswagen Pickup  44.0         4        97.00      52.00  2130.
# 404              Dodge Rampage  32.0         4        135.0      84.00  2295.
# 405                Ford Ranger  28.0         4        120.0      79.00  2625.
# 406                 Chevy S-10  31.0         4        119.0      82.00  2720.
#
#     Acceleration Model  Origin
# ...

# %%
automobili.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 1 to 406
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    object
#  2   Cylinders     406 non-null    object
#  3   Displacement  406 non-null    object
#  4   Horsepower    406 non-null    object
#  5   Weight        406 non-null    object
#  6   Acceleration  406 non-null    object
#  7   Model         406 non-null    object
#  8   Origin        406 non-null    object
# dtypes: object(9)
# memory usage: 28.7+ KB

# %%
automobili.MPG = automobili.MPG.astype(float)

# %%
automobili.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 1 to 406
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    object
#  3   Displacement  406 non-null    object
#  4   Horsepower    406 non-null    object
#  5   Weight        406 non-null    object
#  6   Acceleration  406 non-null    object
#  7   Model         406 non-null    object
#  8   Origin        406 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 28.7+ KB

# %%
automobili.Cylinders = automobili.Cylinders.astype(int)
automobili.Displacement = automobili.Displacement.astype(float)
automobili["Horsepower"] = automobili["Horsepower"].astype(float)
automobili["Weight"] = automobili["Weight"].astype(float)
automobili["Acceleration"] = automobili["Acceleration"].astype(float)
automobili.Model = automobili.Model.astype(int)
automobili.Origin = automobili.Origin.astype("category")

# %%
automobili.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 1 to 406
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    int32
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    float64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int32
#  8   Origin        406 non-null    category
# dtypes: category(1), float64(5), int32(2), object(1)
# memory usage: 22.9+ KB

# %%
automobili.Origin.unique()
# Out:
# ['US', 'Europe', 'Japan']
# Categories (3, object): ['Europe', 'Japan', 'US']

# %%
automobili = pd.read_csv("cars.csv", sep=";", skiprows=[1])
automobili
# Out:
#                            Car   MPG  Cylinders  Displacement  Horsepower  \
# 0    Chevrolet Chevelle Malibu  18.0          8         307.0       130.0
# 1            Buick Skylark 320  15.0          8         350.0       165.0
# 2           Plymouth Satellite  18.0          8         318.0       150.0
# 3                AMC Rebel SST  16.0          8         304.0       150.0
# 4                  Ford Torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 401            Ford Mustang GL  27.0          4         140.0        86.0
# 402          Volkswagen Pickup  44.0          4          97.0        52.0
# 403              Dodge Rampage  32.0          4         135.0        84.0
# 404                Ford Ranger  28.0          4         120.0        79.0
# 405                 Chevy S-10  31.0          4         119.0        82.0
#
#      Weight  Acceleration  Model  Origin
# ...

# %%
automobili.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    float64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    object
# dtypes: float64(5), int64(2), object(2)
# memory usage: 28.7+ KB

# %%
automobili.Origin = automobili.Origin.astype("category")

# %%
automobili.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    float64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int64
#  8   Origin        406 non-null    category
# dtypes: category(1), float64(5), int64(2), object(1)
# memory usage: 26.0+ KB

# %%
automobili.Model.max()
# Out:
# 82

# %%
automobili.Model = automobili.Model.astype("int8")

# %%
automobili.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    int64
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    float64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int8
#  8   Origin        406 non-null    category
# dtypes: category(1), float64(5), int64(1), int8(1), object(1)
# memory usage: 23.3+ KB

# %%
automobili.Cylinders = automobili.Cylinders.astype("uint8")

# %%
automobili.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Car           406 non-null    object
#  1   MPG           406 non-null    float64
#  2   Cylinders     406 non-null    uint8
#  3   Displacement  406 non-null    float64
#  4   Horsepower    406 non-null    float64
#  5   Weight        406 non-null    float64
#  6   Acceleration  406 non-null    float64
#  7   Model         406 non-null    int8
#  8   Origin        406 non-null    category
# dtypes: category(1), float64(5), int8(1), object(1), uint8(1)
# memory usage: 20.5+ KB

# %%
automobili.dtypes
# Out:
# Car               object
# MPG              float64
# Cylinders          uint8
# Displacement     float64
# Horsepower       float64
# Weight           float64
# Acceleration     float64
# Model               int8
# Origin          category
# dtype: object

# %%
automobili.Car = automobili.Car.astype(str)

# %%
automobili.dtypes
# Out:
# Car               object
# MPG              float64
# Cylinders          uint8
# Displacement     float64
# Horsepower       float64
# Weight           float64
# Acceleration     float64
# Model               int8
# Origin          category
# dtype: object

# %%
automobili.empty
# Out:
# False

# %%
automobili.shape
# Out:
# (406, 9)

# %%
automobili.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
automobili.index
# Out:
# RangeIndex(start=0, stop=406, step=1)

# %%
automobili.iloc[[2, 7]]
# Out:
#                   Car   MPG  Cylinders  Displacement  Horsepower  Weight  \
# 2  Plymouth Satellite  18.0          8         318.0       150.0  3436.0
# 7   Plymouth Fury iii  14.0          8         440.0       215.0  4312.0
#
#    Acceleration  Model Origin
# 2          11.0     70     US
# 7           8.5     70     US

# %%
automobili.iloc[0:60]
# Out:
#                                  Car   MPG  Cylinders  Displacement  \
# 0          Chevrolet Chevelle Malibu  18.0          8         307.0
# 1                  Buick Skylark 320  15.0          8         350.0
# 2                 Plymouth Satellite  18.0          8         318.0
# 3                      AMC Rebel SST  16.0          8         304.0
# 4                        Ford Torino  17.0          8         302.0
# 5                   Ford Galaxie 500  15.0          8         429.0
# 6                   Chevrolet Impala  14.0          8         454.0
# 7                  Plymouth Fury iii  14.0          8         440.0
# 8                   Pontiac Catalina  14.0          8         455.0
# 9                 AMC Ambassador DPL  15.0          8         390.0
# 10              Citroen DS-21 Pallas   0.0          4         133.0
# 11  Chevrolet Chevelle Concours (sw)   0.0          8         350.0
# 12                  Ford Torino (sw)   0.0          8         351.0
# ...

# %%
airbnb_df = pd.read_csv("airbnb_new_york_city_listings.csv")
airbnb_df.head(2)
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75356  -73.98559
# 1  LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.68494  -73.95765
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    150              30                 48  2019-11-04
# 1  Entire home/apt     75               1                408  2021-06-29
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.34                               3               341
# 1               5.09                               1               212

# %%
display(airbnb_df)
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                   Large Furnished Room Near B'way　      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
# ...

# %%
airbnb_df
# Out:
#              id                                               name   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3831  Whole flr w/private bdrm, bath & kitchen(pls r...      4869
# 2          5121                                    BlissArtsSpace!      7356
# 3          5136           Spacious Brooklyn Duplex, Patio + Garden      7378
# 4          5178                   Large Furnished Room Near B'way　      8967
# ...         ...                                                ...       ...
# 36719  51447515         Gorgeous 2 Bedroom - in Prime Midtown East  51589519
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...   2971741
# 36721  51450816                                    The Hunter IIII  61391963
# 36722  51451029                        Rockaway Beach Surf Getaway  10123226
# 36723  51451368                       Nyc apt in the middle in nyc  17770287
#
# ...

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36711 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36701 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  object
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df.neighbourhood.unique().shape
# Out:
# (223,)

# %%
airbnb_df.neighbourhood = airbnb_df.neighbourhood.astype("category")

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36711 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36701 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  category
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df.head(2)
# Out:
#      id                                               name  host_id  \
# 0  2595                              Skylit Midtown Castle     2845
# 1  3831  Whole flr w/private bdrm, bath & kitchen(pls r...     4869
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0     Jennifer           Manhattan             Midtown  40.75356  -73.98559
# 1  LisaRoxanne            Brooklyn  Bedford-Stuyvesant  40.68494  -73.95765
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    150              30                 48  2019-11-04
# 1  Entire home/apt     75               1                408  2021-06-29
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.34                               3               341
# 1               5.09                               1               212

# %%
airbnb_df.last_review = airbnb_df.last_review.astype("datetime64[s]")

# %%
airbnb_df.last_review = pd.to_datetime(airbnb_df.last_review)

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36711 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36701 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  category
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df["year"] = airbnb_df.last_review.dt.year

# %%
airbnb_df["year"]
# Out:
# 0        2019.0
# 1        2021.0
# 2        2016.0
# 3        2014.0
# 4        2021.0
#           ...
# 36719       NaN
# 36720       NaN
# 36721       NaN
# 36722       NaN
# 36723       NaN
# Name: year, Length: 36724, dtype: float64

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36711 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36701 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  category
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df.isnull().sum()
# Out:
# id                                   0
# name                                13
# host_id                              0
# host_name                           23
# neighbourhood_group                  0
# neighbourhood                        0
# latitude                             0
# longitude                            0
# room_type                            0
# price                                0
# minimum_nights                       0
# number_of_reviews                    0
# last_review                       9415
# reviews_per_month                 9415
# calculated_host_listings_count       0
# availability_365                     0
# year                              9415
# dtype: int64

# %%
airbnb_df.name.fillna("No name Listing", inplace=True)
# Out:
# C:\Users\brankor\AppData\Local\Temp\ipykernel_25628\29790568.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df.name.fillna("No name Listing", inplace=True)

# %%
airbnb_df.host_name.fillna("J. Doe", inplace=True)
# Out:
# C:\Users\brankor\AppData\Local\Temp\ipykernel_25628\3156200004.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df.host_name.fillna("J. Doe", inplace=True)

# %%
airbnb_df.reviews_per_month.fillna(0.00, inplace=True)
# Out:
# C:\Users\brankor\AppData\Local\Temp\ipykernel_25628\3427412555.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   airbnb_df.reviews_per_month.fillna(0.00, inplace=True)

# %%
airbnb_df.year.fillna(0.00, inplace=True)

# %%
airbnb_df.last_review.fillna("01-01-1970", inplace=True)

# %%
airbnb_df.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# year                              0
# dtype: int64

# %%
airbnb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36724 entries, 0 to 36723
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              36724 non-null  int64
#  1   name                            36724 non-null  object
#  2   host_id                         36724 non-null  int64
#  3   host_name                       36724 non-null  object
#  4   neighbourhood_group             36724 non-null  object
#  5   neighbourhood                   36724 non-null  category
#  6   latitude                        36724 non-null  float64
#  7   longitude                       36724 non-null  float64
#  8   room_type                       36724 non-null  object
#  9   price                           36724 non-null  int64
#  10  minimum_nights                  36724 non-null  int64
#  11  number_of_reviews               36724 non-null  int64
# ...

# %%
airbnb_df.year = airbnb_df.year.astype("int16")

# %%
airbnb_df.name = airbnb_df.name.str.strip()

# %%
podskup_df = pd.DataFrame(airbnb_df[::10])
podskup_df
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 10         7064  Amazing location! Wburg. Large, bright & tranquil      17297
# 20        11943                          Country space in the city      45445
# 30        15220                Best Location in NYC! TIMES SQUARE!      59734
# 40        17037                            Lovely EV Artist's Home      66035
# ...         ...                                                ...        ...
# 36680  51403339                             ECO GLAM APARTMENT UES  415997367
# 36690  51418549                    One Bedroom  -Battery Park City   20761945
# 36700  51427125                                        Waldo Court  228426015
# 36710  51444181               It's a Delightful Day in Bed-Stuy! 2  395798646
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...    2971741
#
# ...

# %%
podskup_df.reset_index()
# podskup_df = podskup_df.reset_index()
# podskup_df.reset_index(inplace=True)
# Out:
#       index        id                                               name  \
# 0         0      2595                              Skylit Midtown Castle
# 1        10      7064  Amazing location! Wburg. Large, bright & tranquil
# 2        20     11943                          Country space in the city
# 3        30     15220                Best Location in NYC! TIMES SQUARE!
# 4        40     17037                            Lovely EV Artist's Home
# ...     ...       ...                                                ...
# 3668  36680  51403339                             ECO GLAM APARTMENT UES
# 3669  36690  51418549                    One Bedroom  -Battery Park City
# 3670  36700  51427125                                        Waldo Court
# 3671  36710  51444181               It's a Delightful Day in Bed-Stuy! 2
# 3672  36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...
#
#         host_id         host_name neighbourhood_group      neighbourhood  \
# ...

# %%
podskup_df
# Out:
#              id                                               name    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 10         7064  Amazing location! Wburg. Large, bright & tranquil      17297
# 20        11943                          Country space in the city      45445
# 30        15220                Best Location in NYC! TIMES SQUARE!      59734
# 40        17037                            Lovely EV Artist's Home      66035
# ...         ...                                                ...        ...
# 36680  51403339                             ECO GLAM APARTMENT UES  415997367
# 36690  51418549                    One Bedroom  -Battery Park City   20761945
# 36700  51427125                                        Waldo Court  228426015
# 36710  51444181               It's a Delightful Day in Bed-Stuy! 2  395798646
# 36720  51449962  Charming UWS 1-bdrm, 1-office, 1/2 block to Ct...    2971741
#
# ...

# %%
podskup_df.reset_index(inplace=True, drop=True)

# %%
podskup_df.head(3)
# Out:
#       id                                               name  host_id  \
# 0   2595                              Skylit Midtown Castle     2845
# 1   7064  Amazing location! Wburg. Large, bright & tranquil    17297
# 2  11943                          Country space in the city    45445
#
#   host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0  Jennifer           Manhattan       Midtown  40.75356  -73.98559
# 1    Joelle            Brooklyn  Williamsburg  40.71248  -73.95881
# 2   Harriet            Brooklyn      Flatbush  40.63702  -73.96327
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0  Entire home/apt    150              30                 48  2019-11-04
# 1     Private room     90              27                  9  2015-08-31
# 2     Private room    150              30                  0  1970-01-01
#
#    reviews_per_month  calculated_host_listings_count  availability_365  year
# ...

# %%
airbnb_df.drop(["id", "name", "host_id", "host_name", "latitude", "longitude"], axis=1, inplace=True)

# %%
airbnb_df
# Out:
#       neighbourhood_group       neighbourhood        room_type  price  \
# 0               Manhattan             Midtown  Entire home/apt    150
# 1                Brooklyn  Bedford-Stuyvesant  Entire home/apt     75
# 2                Brooklyn  Bedford-Stuyvesant     Private room     60
# 3                Brooklyn         Sunset Park  Entire home/apt    275
# 4               Manhattan             Midtown     Private room     61
# ...                   ...                 ...              ...    ...
# 36719           Manhattan             Midtown  Entire home/apt    255
# 36720           Manhattan     Upper West Side  Entire home/apt    306
# 36721           Manhattan     Upper East Side  Entire home/apt     63
# 36722              Queens             Arverne     Private room     75
# 36723           Manhattan         Murray Hill  Entire home/apt    115
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
airbnb_df["Nova kolona"] = 55

# %%
airbnb_df.head(3)
# Out:
#   neighbourhood_group       neighbourhood        room_type  price  \
# 0           Manhattan             Midtown  Entire home/apt    150
# 1            Brooklyn  Bedford-Stuyvesant  Entire home/apt     75
# 2            Brooklyn  Bedford-Stuyvesant     Private room     60
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0              30                 48  2019-11-04               0.34
# 1               1                408  2021-06-29               5.09
# 2              30                 50  2016-06-05               0.55
#
#    calculated_host_listings_count  availability_365  year  Nova kolona
# 0                               3               341  2019           55
# 1                               1               212  2021           55
# 2                               1               365  2016           55

# %%
airbnb_df["minimal_revenue"] = airbnb_df.price * airbnb_df.minimum_nights

# %%
airbnb_df.head(3)
# Out:
#   neighbourhood_group       neighbourhood        room_type  price  \
# 0           Manhattan             Midtown  Entire home/apt    150
# 1            Brooklyn  Bedford-Stuyvesant  Entire home/apt     75
# 2            Brooklyn  Bedford-Stuyvesant     Private room     60
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0              30                 48  2019-11-04               0.34
# 1               1                408  2021-06-29               5.09
# 2              30                 50  2016-06-05               0.55
#
#    calculated_host_listings_count  availability_365  year  Nova kolona  \
# 0                               3               341  2019           55
# 1                               1               212  2021           55
# 2                               1               365  2016           55
#
#    minimal_revenue
# 0             4500
# 1               75
# 2             1800

# %%
airbnb_df.price > 3000
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 36719    False
# 36720    False
# 36721    False
# 36722    False
# 36723    False
# Name: price, Length: 36724, dtype: bool

# %%
airbnb_df[airbnb_df.price > 3000]
# Out:
#       neighbourhood_group       neighbourhood        room_type  price  \
# 2064            Manhattan     Upper West Side  Entire home/apt   6000
# 2174            Manhattan           Chinatown  Entire home/apt   5250
# 2206             Brooklyn        Clinton Hill  Entire home/apt   6500
# 2215            Manhattan        East Village  Entire home/apt   3750
# 3475            Manhattan        East Village     Private room   9990
# 3853            Manhattan         East Harlem  Entire home/apt   9999
# 5153            Manhattan             Chelsea  Entire home/apt   3517
# 7309            Manhattan     Lower East Side     Private room   7314
# 8906            Manhattan             Tribeca  Entire home/apt   5000
# 9282            Manhattan   Greenwich Village  Entire home/apt   6000
# 10395              Queens    Long Island City  Entire home/apt  10000
# 14116              Queens           Briarwood     Private room   9000
# ...

# %%
airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 36719     True
# 36720     True
# 36721     True
# 36722     True
# 36723     True
# Name: neighbourhood_group, Length: 36724, dtype: bool

# %%
airbnb_df[airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])]
# Out:
#       neighbourhood_group    neighbourhood        room_type  price  \
# 0               Manhattan          Midtown  Entire home/apt    150
# 4               Manhattan          Midtown     Private room     61
# 5               Manhattan  Upper West Side     Private room     75
# 8               Manhattan      East Harlem     Private room     65
# 9               Manhattan      East Harlem     Private room     62
# ...                   ...              ...              ...    ...
# 36719           Manhattan          Midtown  Entire home/apt    255
# 36720           Manhattan  Upper West Side  Entire home/apt    306
# 36721           Manhattan  Upper East Side  Entire home/apt     63
# 36722              Queens          Arverne     Private room     75
# 36723           Manhattan      Murray Hill  Entire home/apt    115
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                  30                 48  2019-11-04               0.34
# ...

# %%
airbnb_df[(airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])) & (airbnb_df.price > 6000)]
# Out:
#       neighbourhood_group     neighbourhood        room_type  price  \
# 3475            Manhattan      East Village     Private room   9990
# 3853            Manhattan       East Harlem  Entire home/apt   9999
# 7309            Manhattan   Lower East Side     Private room   7314
# 10395              Queens  Long Island City  Entire home/apt  10000
# 14116              Queens         Briarwood     Private room   9000
# 15760           Manhattan   Upper West Side  Entire home/apt  10000
# 16047              Queens           Astoria  Entire home/apt  10000
# 18466           Manhattan   Lower East Side     Private room   7000
# 20324           Manhattan       Murray Hill      Shared room  10000
# 20391           Manhattan   Lower East Side  Entire home/apt   9999
# 21401           Manhattan   Lower East Side     Private room   9999
# 21403           Manhattan   Lower East Side     Private room   9999
# 21404           Manhattan   Lower East Side     Private room   9999
# ...

# %%
airbnb_df[(airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])) & (airbnb_df.price > 6000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17 entries, 3475 to 27624
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             17 non-null     object
#  1   neighbourhood                   17 non-null     category
#  2   room_type                       17 non-null     object
#  3   price                           17 non-null     int64
#  4   minimum_nights                  17 non-null     int64
#  5   number_of_reviews               17 non-null     int64
#  6   last_review                     17 non-null     datetime64[s]
#  7   reviews_per_month               17 non-null     float64
#  8   calculated_host_listings_count  17 non-null     int64
#  9   availability_365                17 non-null     int64
#  10  year                            17 non-null     int16
#  11  Nova kolona                     17 non-null     int64
# ...

# %%
airbnb_df[(airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])) | (airbnb_df.price > 6000)].head(4)
# Out:
#   neighbourhood_group    neighbourhood        room_type  price  \
# 0           Manhattan          Midtown  Entire home/apt    150
# 4           Manhattan          Midtown     Private room     61
# 5           Manhattan  Upper West Side     Private room     75
# 8           Manhattan      East Harlem     Private room     65
#
#    minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0              30                 48  2019-11-04               0.34
# 4               2                485  2021-07-18               3.63
# 5               2                118  2017-07-12               0.90
# 8              30                  0  1970-01-01               0.00
#
#    calculated_host_listings_count  availability_365  year  Nova kolona  \
# 0                               3               341  2019           55
# 4                               1               255  2021           55
# 5                               1                 0  2017           55
# ...

# %%
airbnb_df[(airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])) | (airbnb_df.price > 6000)].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21011 entries, 0 to 36723
# Data columns (total 13 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   neighbourhood_group             21011 non-null  object
#  1   neighbourhood                   21011 non-null  category
#  2   room_type                       21011 non-null  object
#  3   price                           21011 non-null  int64
#  4   minimum_nights                  21011 non-null  int64
#  5   number_of_reviews               21011 non-null  int64
#  6   last_review                     21011 non-null  datetime64[s]
#  7   reviews_per_month               21011 non-null  float64
#  8   calculated_host_listings_count  21011 non-null  int64
#  9   availability_365                21011 non-null  int64
#  10  year                            21011 non-null  int16
#  11  Nova kolona                     21011 non-null  int64
# ...

# %%
# airbnb_df[(airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])) and (airbnb_df.price > 6000)].head(4)

# %%
airbnb_df[(airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])) & (airbnb_df.price > 6000)].head(4)
# Out:
#       neighbourhood_group     neighbourhood        room_type  price  \
# 3475            Manhattan      East Village     Private room   9990
# 3853            Manhattan       East Harlem  Entire home/apt   9999
# 7309            Manhattan   Lower East Side     Private room   7314
# 10395              Queens  Long Island City  Entire home/apt  10000
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 3475               30                  9  2016-06-13               0.14
# 3853               30                  1  2015-01-02               0.01
# 7309               99                  6  2016-01-01               0.09
# 10395              30                 28  2017-11-14               0.47
#
#        calculated_host_listings_count  availability_365  year  Nova kolona  \
# 3475                                1                 0  2016           55
# 3853                                1                 0  2015           55
# ...

# %%
airbnb_df.neighbourhood_group.str.contains("Manh").any()
# Out:
# True

# %%
airbnb_df.neighbourhood_group.str.contains("Manh").all()
# Out:
# False

# %%
airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"]).any()
# Out:
# True

# %%
airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"]).all()
# Out:
# False

# %%
airbnb_reduced = pd.DataFrame(airbnb_df[airbnb_df.neighbourhood_group.isin(["Queens", "Manhattan"])])
airbnb_reduced
# Out:
#       neighbourhood_group    neighbourhood        room_type  price  \
# 0               Manhattan          Midtown  Entire home/apt    150
# 4               Manhattan          Midtown     Private room     61
# 5               Manhattan  Upper West Side     Private room     75
# 8               Manhattan      East Harlem     Private room     65
# 9               Manhattan      East Harlem     Private room     62
# ...                   ...              ...              ...    ...
# 36719           Manhattan          Midtown  Entire home/apt    255
# 36720           Manhattan  Upper West Side  Entire home/apt    306
# 36721           Manhattan  Upper East Side  Entire home/apt     63
# 36722              Queens          Arverne     Private room     75
# 36723           Manhattan      Murray Hill  Entire home/apt    115
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0                  30                 48  2019-11-04               0.34
# ...

# %%
airbnb_reduced.neighbourhood_group.isin(["Queens", "Manhattan"]).all()
# Out:
# True

# %%
airbnb_reduced.neighbourhood_group.isin(["Queens", "Manhattan"]).any()
# Out:
# True

# %%
help(airbnb_reduced.neighbourhood_group.isin(["Queens", "Manhattan"]).any)
# Out:
# Help on method any in module pandas.core.series:
#
# any(*, axis: 'Axis' = 0, bool_only: 'bool' = False, skipna: 'bool' = True, **kwargs) -> 'bool' method of pandas.core.series.Series instance
#     Return whether any element is True, potentially over an axis.
#
#     Returns False unless there is at least one element within a series or
#     along a Dataframe axis that is True or equivalent (e.g. non-zero or
#     non-empty).
#
#     Parameters
#     ----------
#     axis : {0 or 'index', 1 or 'columns', None}, default 0
#         Indicate which axis or axes should be reduced. For `Series` this parameter
#         is unused and defaults to 0.
#
#         * 0 / 'index' : reduce the index, return a Series whose index is the
#           original column labels.
#         * 1 / 'columns' : reduce the columns, return a Series whose index is the
#           original index.
#         * None : reduce all axes, return a scalar.
#
#     bool_only : bool, default False
# ...

# %%
airbnb_df.price.min()
# Out:
# 0

# %%
airbnb_df.price.median()
# Out:
# 108.0

# %%
airbnb_df.price.mean()
# Out:
# 160.10905674763097

# %%
airbnb_df.price.max() - airbnb_df.price.min()
# Out:
# 10000

# %%
airbnb_df.price.quantile(q=0.25)
# Out:
# 10000.0

# %%
airbnb_df.price.quantile(q=0.5)
# Out:
# 108.0

# %%
airbnb_df.price.quantile(q=0.75)
# Out:
# 175.0

# %%
airbnb_df.price.quantile(q=1)
# Out:
# 10000.0

# %%
airbnb_df.price.max()
# Out:
# 10000

# %%
airbnb_df.neighbourhood_group.value_counts().sort_values(ascending=True)
# Out:
# neighbourhood_group
# Staten Island      315
# Bronx             1026
# Queens            4902
# Brooklyn         14376
# Manhattan        16105
# Name: count, dtype: int64

# %%
airbnb_df.describe()
# Out:
#               price  minimum_nights  number_of_reviews          last_review  \
# count  36724.000000    36724.000000       36724.000000                36724
# mean     160.109057       22.482083          22.854836  2007-02-11 08:02:25
# min        0.000000        1.000000           0.000000  1970-01-01 00:00:00
# 25%       67.000000        3.000000           0.000000  1970-01-01 00:00:00
# 50%      108.000000       30.000000           4.000000  2019-08-31 00:00:00
# 75%      175.000000       30.000000          19.000000  2021-05-17 00:00:00
# max    10000.000000     1250.000000         998.000000  2021-08-04 00:00:00
# std      293.888431       28.361534          49.188479                  NaN
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# count       36724.000000                    36724.000000      36724.000000
# mean            1.022812                       13.432306        122.570608
# ...

# %%
airbnb_df.describe(include="all")
# Out:
#        neighbourhood_group       neighbourhood        room_type         price  \
# count                36724               36724            36724  36724.000000
# unique                   5                 223                4           NaN
# top              Manhattan  Bedford-Stuyvesant  Entire home/apt           NaN
# freq                 16105                2690            19484           NaN
# mean                   NaN                 NaN              NaN    160.109057
# min                    NaN                 NaN              NaN      0.000000
# 25%                    NaN                 NaN              NaN     67.000000
# 50%                    NaN                 NaN              NaN    108.000000
# 75%                    NaN                 NaN              NaN    175.000000
# max                    NaN                 NaN              NaN  10000.000000
# std                    NaN                 NaN              NaN    293.888431
#
# ...

# %%
type(airbnb_df.describe(include="all"))
# Out:
# pandas.core.frame.DataFrame

# %%
stat_airbnb = airbnb_df.describe(include="all")
stat_airbnb
# Out:
#        neighbourhood_group       neighbourhood        room_type         price  \
# count                36724               36724            36724  36724.000000
# unique                   5                 223                4           NaN
# top              Manhattan  Bedford-Stuyvesant  Entire home/apt           NaN
# freq                 16105                2690            19484           NaN
# mean                   NaN                 NaN              NaN    160.109057
# min                    NaN                 NaN              NaN      0.000000
# 25%                    NaN                 NaN              NaN     67.000000
# 50%                    NaN                 NaN              NaN    108.000000
# 75%                    NaN                 NaN              NaN    175.000000
# max                    NaN                 NaN              NaN  10000.000000
# std                    NaN                 NaN              NaN    293.888431
#
# ...

# %%
stat_airbnb.loc["std"].dropna().sort_values().reset_index()
# Out:
#                             index           std
# 0                     Nova kolona           0.0
# 1               reviews_per_month      3.374019
# 2                  minimum_nights     28.361534
# 3  calculated_host_listings_count     46.293004
# 4               number_of_reviews     49.188479
# 5                availability_365    138.765815
# 6                           price    293.888431
# 7                            year    881.743887
# 8                 minimal_revenue  13745.108195

# %%
stat_airbnb.loc["std"]
# Out:
# neighbourhood_group                        NaN
# neighbourhood                              NaN
# room_type                                  NaN
# price                               293.888431
# minimum_nights                       28.361534
# number_of_reviews                    49.188479
# last_review                                NaN
# reviews_per_month                     3.374019
# calculated_host_listings_count       46.293004
# availability_365                    138.765815
# year                                881.743887
# Nova kolona                                0.0
# minimal_revenue                   13745.108195
# Name: std, dtype: object

# %%
stat_airbnb.loc["std"].dropna().idxmax()
# Out:
# 'minimal_revenue'

# %%
stat_airbnb.loc["std"].idxmax()
# Out:
# 'minimal_revenue'

# %%
stat_airbnb["minimal_revenue"]
# Out:
# count     3.672400e+04
# unique             NaN
# top                NaN
# freq               NaN
# mean      3.562474e+03
# min       0.000000e+00
# 25%       4.600000e+02
# 50%       1.860000e+03
# 75%       3.900000e+03
# max       1.170000e+06
# std       1.374511e+04
# Name: minimal_revenue, dtype: float64

# %%
novo = stat_airbnb.loc["std"].dropna().sort_values().reset_index()

# %%
novo.iloc[-1]
# Out:
# index    minimal_revenue
# std         13745.108195
# Name: 8, dtype: object

# %%
novo.loc[8]
# Out:
# index    minimal_revenue
# std         13745.108195
# Name: 8, dtype: object

# %%
airbnb_df.corr(numeric_only=all)
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000       -0.004452          -0.030849
# minimum_nights                 -0.004452        1.000000          -0.143130
# number_of_reviews              -0.030849       -0.143130           1.000000
# reviews_per_month              -0.011955       -0.151884           0.359701
# calculated_host_listings_count -0.000460        0.059466          -0.102862
# availability_365                0.069875       -0.020994           0.104905
# year                           -0.053948       -0.128863           0.273289
# Nova kolona                          NaN             NaN                NaN
# minimal_revenue                 0.623080        0.376846          -0.053733
#
#                                 reviews_per_month  \
# price                                   -0.011955
# minimum_nights                          -0.151884
# number_of_reviews                        0.359701
# ...

# %%
corr_df = airbnb_df.corr(numeric_only=all)

# %%
corr_df["minimal_revenue"].drop(["minimal_revenue"]).dropna()
# Out:
# price                             0.623080
# minimum_nights                    0.376846
# number_of_reviews                -0.053733
# reviews_per_month                -0.051499
# calculated_host_listings_count    0.016462
# availability_365                  0.034378
# year                             -0.072852
# Name: minimal_revenue, dtype: float64

# %%
corr_df["minimal_revenue"].drop(["minimal_revenue"]).dropna().abs().max()
# Out:
# 0.6230799400103795

# %%
corr_df["minimal_revenue"].drop(["minimal_revenue"]).dropna().abs().idxmax()
# Out:
# 'price'

# %%
corr_df["minimal_revenue"][corr_df["minimal_revenue"] == corr_df["minimal_revenue"].drop(["minimal_revenue"]).dropna().abs().max()]
# Out:
# price    0.62308
# Name: minimal_revenue, dtype: float64

# %%
corr_df["minimal_revenue"].drop(["minimal_revenue"]).dropna().abs().sort_values().reset_index().iloc[-1]
# Out:
# index                price
# minimal_revenue    0.62308
# Name: 6, dtype: object

# %%
corr_df["minimal_revenue"].drop(["minimal_revenue"]).dropna().abs().sort_values(ascending=False).reset_index().iloc[0]
# Out:
# index                price
# minimal_revenue    0.62308
# Name: 0, dtype: object

# %%
corr_df["minimal_revenue"].drop(["minimal_revenue"]).dropna().abs().sort_values(ascending=False).reset_index()
# Out:
#                             index  minimal_revenue
# 0                           price         0.623080
# 1                  minimum_nights         0.376846
# 2                            year         0.072852
# 3               number_of_reviews         0.053733
# 4               reviews_per_month         0.051499
# 5                availability_365         0.034378
# 6  calculated_host_listings_count         0.016462

# %%
airbnb_df["minimal_revenue"].corr(airbnb_df["price"])
# Out:
# 0.6230799400103887

# %%
airbnb_df["minimal_revenue"]
# Out:
# 0        4500
# 1          75
# 2        1800
# 3        1375
# 4         122
#          ...
# 36719    7905
# 36720    1530
# 36721    1890
# 36722      75
# 36723    3450
# Name: minimal_revenue, Length: 36724, dtype: int64

# %%
airbnb_df.describe(include="all")
# Out:
#        neighbourhood_group       neighbourhood        room_type         price  \
# count                36724               36724            36724  36724.000000
# unique                   5                 223                4           NaN
# top              Manhattan  Bedford-Stuyvesant  Entire home/apt           NaN
# freq                 16105                2690            19484           NaN
# mean                   NaN                 NaN              NaN    160.109057
# min                    NaN                 NaN              NaN      0.000000
# 25%                    NaN                 NaN              NaN     67.000000
# 50%                    NaN                 NaN              NaN    108.000000
# 75%                    NaN                 NaN              NaN    175.000000
# max                    NaN                 NaN              NaN  10000.000000
# std                    NaN                 NaN              NaN    293.888431
#
# ...

# %% [markdown]
# Pronadite kolonu koaj u data farme airbnb ima najmanji mean, nadi koja kolona ima najvecu korleaciju s tom kolone

# %%
df_primjer_stat = airbnb_df.describe(include="all")
naziv_kolone_s_njamanjim_mean = df_primjer_stat.loc["mean"].dropna().drop(["last_review"]).sort_values().idxmin(0)
naziv_kolone_s_njamanjim_mean
# Out:
# 'reviews_per_month'

# %%
df_corr_primjer = airbnb_df.corr(numeric_only=True)
df_corr_primjer[naziv_kolone_s_njamanjim_mean].dropna().abs().sort_values().drop([naziv_kolone_s_njamanjim_mean]).idxmax()
# Out:
# 'number_of_reviews'

# %%
df_corr_primjer[naziv_kolone_s_njamanjim_mean].dropna().abs().sort_values().drop([naziv_kolone_s_njamanjim_mean]).reset_index().iloc[-1]
# Out:
# index                number_of_reviews
# reviews_per_month             0.359701
# Name: 6, dtype: object

# %%
airbnb_df[["room_type", "price", "minimal_revenue"]]
# Out:
#              room_type  price  minimal_revenue
# 0      Entire home/apt    150             4500
# 1      Entire home/apt     75               75
# 2         Private room     60             1800
# 3      Entire home/apt    275             1375
# 4         Private room     61              122
# ...                ...    ...              ...
# 36719  Entire home/apt    255             7905
# 36720  Entire home/apt    306             1530
# 36721  Entire home/apt     63             1890
# 36722     Private room     75               75
# 36723  Entire home/apt    115             3450
#
# [36724 rows x 3 columns]

# %%
airbnb_df[["room_type", "price", "minimal_revenue"]].groupby("room_type").mean()
# Out:
#                       price  minimal_revenue
# room_type
# Entire home/apt  213.324779      4949.334480
# Hotel room       293.262548      2662.552124
# Private room      96.617690      1963.337077
# Shared room      107.978297      2575.096828

# %%
airbnb_df[["room_type", "price", "minimal_revenue"]].groupby("room_type").min()
# Out:
#                  price  minimal_revenue
# room_type
# Entire home/apt     10               29
# Hotel room           0                0
# Private room        10               18
# Shared room         15               15

# %%
airbnb_df[["room_type", "price", "minimal_revenue"]].groupby("room_type").std()
# Out:
#                       price  minimal_revenue
# room_type
# Entire home/apt  310.830582     15674.139091
# Hotel room       279.581360      6290.617826
# Private room     249.534072     10731.841625
# Shared room      451.337586     17079.169710

# %%
airbnb_df[["room_type", "price", "minimal_revenue"]].groupby("room_type", as_index=False).std()
# Out:
#          room_type       price  minimal_revenue
# 0  Entire home/apt  310.830582     15674.139091
# 1       Hotel room  279.581360      6290.617826
# 2     Private room  249.534072     10731.841625
# 3      Shared room  451.337586     17079.169710

# %%
airbnb_df[["room_type", "price", "minimal_revenue"]].groupby("room_type").std().reset_index()
# Out:
#          room_type       price  minimal_revenue
# 0  Entire home/apt  310.830582     15674.139091
# 1       Hotel room  279.581360      6290.617826
# 2     Private room  249.534072     10731.841625
# 3      Shared room  451.337586     17079.169710

# %%
airbnb_df[["room_type", "price", "minimal_revenue", "minimum_nights"]].groupby(["room_type","minimum_nights"], as_index=True).mean()
# Out:
#                                      price  minimal_revenue
# room_type       minimum_nights
# Entire home/apt 1               265.781380       265.781380
#                 2               203.050482       406.100964
#                 3               231.303750       693.911250
#                 4               221.855244       887.420975
#                 5               229.657191      1148.285953
# ...                                    ...              ...
# Shared room     75               50.000000      3750.000000
#                 100              62.000000      6200.000000
#                 120              35.000000      4200.000000
#                 180             110.000000     19800.000000
#                 999              31.000000     30969.000000
#
# [216 rows x 2 columns]

# %%
airbnb_df[["room_type", "price", "minimal_revenue", "minimum_nights"]].groupby(["room_type","minimum_nights"], as_index=True)

# %%
airbnb_df.columns
# Out:
# Index(['neighbourhood_group', 'neighbourhood', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'year', 'Nova kolona', 'minimal_revenue'],
#       dtype='object')

# %%
moj_x = {"x": [10, 50, 80, 110, 140, -10 , -50, 80 , 90, 110, 1000, 2000, -50000, 50000] }
moj_x = {"x": [10, 50, 80, 110, 140, -10 , -50, 80 , 90, 110] }
moj_x_df = pd.DataFrame(moj_x)

# %%
import numpy as np
#
moj_x_df["-x"] = -1*moj_x_df["x"]
moj_x_df["-x+5"] = moj_x_df["x"] * -1 + 5 
moj_x_df["5x-3"] = moj_x_df["x"] * 5 + -3
moj_x_df["x^2"] = moj_x_df["x"] ** 2 
moj_x_df["x^3"] = moj_x_df["x"] ** 3 
moj_x_df["x^4"] = moj_x_df["x"] ** 4

# %%
moj_x_df["-x"] = -1*moj_x_df["x"] + np.random.randint(low=10, high=200, size=len(moj_x_df["x"]))
moj_x_df["-x+5"] = moj_x_df["x"] * -1 + 5 + np.random.randint(low=10, high=200, size=len(moj_x_df["x"]))
moj_x_df["5x-3"] = moj_x_df["x"] * 5 + -3 + np.random.randint(low=10, high=200, size=len(moj_x_df["x"]))
moj_x_df["x^2"] = moj_x_df["x"] ** 2  + np.random.randint(low=10, high=20, size=len(moj_x_df["x"]))
moj_x_df["x^3"] = moj_x_df["x"] ** 3 + np.random.randint(low=10, high=20, size=len(moj_x_df["x"]))
moj_x_df["x^4"] = moj_x_df["x"] ** 4+ np.random.randint(low=10, high=20, size=len(moj_x_df["x"]))

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(moj_x_df[["x", "-x", "-x+5"]], figsize=(15, 8))
# Out:
# array([[<Axes: xlabel='x', ylabel='x'>, <Axes: xlabel='-x', ylabel='x'>,
#         <Axes: xlabel='-x+5', ylabel='x'>],
#        [<Axes: xlabel='x', ylabel='-x'>,
#         <Axes: xlabel='-x', ylabel='-x'>,
#         <Axes: xlabel='-x+5', ylabel='-x'>],
#        [<Axes: xlabel='x', ylabel='-x+5'>,
#         <Axes: xlabel='-x', ylabel='-x+5'>,
#         <Axes: xlabel='-x+5', ylabel='-x+5'>]], dtype=object)

# %%
moj_x_df[["x", "-x", "-x+5"]].corr()
# Out:
#              x        -x      -x+5
# x     1.000000 -0.835932 -0.670469
# -x   -0.835932  1.000000  0.619197
# -x+5 -0.670469  0.619197  1.000000

# %%
scatter_matrix(moj_x_df[["x", "x^2", "x^4"]], figsize=(15, 8))
# Out:
# array([[<Axes: xlabel='x', ylabel='x'>, <Axes: xlabel='x^2', ylabel='x'>,
#         <Axes: xlabel='x^4', ylabel='x'>],
#        [<Axes: xlabel='x', ylabel='x^2'>,
#         <Axes: xlabel='x^2', ylabel='x^2'>,
#         <Axes: xlabel='x^4', ylabel='x^2'>],
#        [<Axes: xlabel='x', ylabel='x^4'>,
#         <Axes: xlabel='x^2', ylabel='x^4'>,
#         <Axes: xlabel='x^4', ylabel='x^4'>]], dtype=object)

# %%
moj_x_df[["x", "x^2", "x^4"]].corr()
# Out:
#             x       x^2       x^4
# x    1.000000  0.857778  0.732284
# x^2  0.857778  1.000000  0.944281
# x^4  0.732284  0.944281  1.000000

# %%
from pandas.plotting import autocorrelation_plot

# %%
kupci_df = pd.read_csv("./mall_customers.csv")
kupci_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
autocorrelation_plot(kupci_df.Age)
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
autocorrelation_plot(kupci_df["Spending Score (1-100)"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
kupci_df.corr(numeric_only=True)
# Out:
#                         CustomerID       Age  Annual Income (k$)  \
# CustomerID                1.000000 -0.026763            0.977548
# Age                      -0.026763  1.000000           -0.012398
# Annual Income (k$)        0.977548 -0.012398            1.000000
# Spending Score (1-100)    0.013835 -0.327227            0.009903
#
#                         Spending Score (1-100)
# CustomerID                            0.013835
# Age                                  -0.327227
# Annual Income (k$)                    0.009903
# Spending Score (1-100)                1.000000

# %%
autocorrelation_plot(kupci_df.Age)
autocorrelation_plot(kupci_df["Spending Score (1-100)"])
autocorrelation_plot(kupci_df["Annual Income (k$)"])
# Out:
# <Axes: xlabel='Lag', ylabel='Autocorrelation'>

# %%
airbnb_df
# Out:
#       neighbourhood_group       neighbourhood        room_type  price  \
# 0               Manhattan             Midtown  Entire home/apt    150
# 1                Brooklyn  Bedford-Stuyvesant  Entire home/apt     75
# 2                Brooklyn  Bedford-Stuyvesant     Private room     60
# 3                Brooklyn         Sunset Park  Entire home/apt    275
# 4               Manhattan             Midtown     Private room     61
# ...                   ...                 ...              ...    ...
# 36719           Manhattan             Midtown  Entire home/apt    255
# 36720           Manhattan     Upper West Side  Entire home/apt    306
# 36721           Manhattan     Upper East Side  Entire home/apt     63
# 36722              Queens             Arverne     Private room     75
# 36723           Manhattan         Murray Hill  Entire home/apt    115
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# ...

# %%
pd.pivot_table(airbnb_df, values=["price"], index=["room_type"], columns=["year"], aggfunc="median")
# Out:
#                  price                                                   \
# year              0      2010   2011   2012   2013   2014   2015   2016
# room_type
# Entire home/apt  180.0  228.0  165.0  150.0  150.0  170.0  150.0  150.0
# Hotel room       370.0    NaN    NaN    NaN    NaN    NaN    NaN  349.0
# Private room      68.0    NaN  349.0   90.0  100.0   80.0   75.0   65.0
# Shared room       65.0    NaN    NaN    NaN   50.0   82.0   61.5   95.0
#
#
# year              2017   2018   2019   2020   2021
# room_type
# Entire home/apt  149.0  150.0  150.0  148.0  150.0
# Hotel room       248.0  125.0  291.0  211.5  165.0
# Private room      65.0   65.0   69.0   63.0   68.0
# Shared room       51.0   57.0   55.0   45.0   40.0

# %%
airbnb_df[(airbnb_df.room_type == "Private room") & (airbnb_df.year == 2014)].price.median()
# Out:
# 80.0

# %%
pd.pivot_table(airbnb_df, values=["price"], index=["room_type"], columns=["year"], aggfunc="mean")
# Out:
#                       price                                               \
# year                   0      2010   2011   2012        2013        2014
# room_type
# Entire home/apt  262.485149  228.0  191.8  156.0  170.666667  184.879032
# Hotel room       407.655738    NaN    NaN    NaN         NaN         NaN
# Private room     113.444228    NaN  349.0  112.9  102.454545   95.848485
# Shared room      104.267760    NaN    NaN    NaN   50.000000   82.000000
#
#                                                                              \
# year                   2015        2016        2017        2018        2019
# room_type
# Entire home/apt  228.021739  187.533696  205.882831  178.282708  197.652335
# Hotel room              NaN  349.000000  241.000000  128.333333  291.718750
# Private room      83.240449  104.994702   78.045455   82.330695   83.535901
# Shared room      166.300000  117.058824   67.700000  107.535714  239.241379
#
#
# year                   2020        2021
# ...

# %%
airbnb_df[(airbnb_df.room_type == "Hotel room") & (airbnb_df.year.isin([2010, 2011, 2012, 2013]))]
# Out:
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, year, Nova kolona, minimal_revenue]
# Index: []

# %%
airbnb_df[(airbnb_df.room_type == "Private room") & (airbnb_df.year.isin([2010]))]
# Out:
# Empty DataFrame
# Columns: [neighbourhood_group, neighbourhood, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365, year, Nova kolona, minimal_revenue]
# Index: []

# %%
airbnb_df[(airbnb_df.room_type == "Private room") & (airbnb_df.year == 2014)].price.mean()
# Out:
# 95.84848484848484

# %%
pd.pivot_table(ocjene, index=["gender"], values=["age", "hours", "grade", "exercise"], aggfunc="mean")
# Out:
#            age  exercise    grade   hours
# gender
# female  16.568     3.047  82.7173  10.932
# male    16.589     2.954  82.3948  11.045

# %%
pd.pivot_table(ocjene, index=["gender"], values=["age", "hours", "grade", "exercise"], aggfunc="mean", margins=True)
# Out:
#             age  exercise     grade    hours
# gender
# female  16.5680    3.0470  82.71730  10.9320
# male    16.5890    2.9540  82.39480  11.0450
# All     16.5785    3.0005  82.55605  10.9885

# %%
pd.pivot_table(airbnb_df, values=["price", "minimal_revenue"], index=["room_type"], aggfunc="mean", margins=True)
# Out:
#                  minimal_revenue       price
# room_type
# Entire home/apt      4949.334480  213.324779
# Hotel room           2662.552124  293.262548
# Private room         1963.337077   96.617690
# Shared room          2575.096828  107.978297
# All                  3562.474268  160.109057

# %%
voce_podatci = {
    "Ime": ["Jabuka", "Banana", "Narandža", "Jagoda", "Grožđe", "Jabuka", "Banana", "Jabuka", "Banana",],
    "Boja": ["Crvena", "Žuta", "Narancasta", "Crvena", "Zelena", "Crvena", "Žuta", "Crvena", "Žuta",],
    "Težina (g)": [150, 120, 180, 15, 5, 1200, 200, 300, 500,],
    "Cijena po kg (EUR)": [2, 1, 4, 10, 20, 19, 8, 9, 5,]
}

voce_df = pd.DataFrame(voce_podatci)
voce_df
# Out:
#         Ime        Boja  Težina (g)  Cijena po kg (EUR)
# 0    Jabuka      Crvena         150                   2
# 1    Banana        Žuta         120                   1
# 2  Narandža  Narancasta         180                   4
# 3    Jagoda      Crvena          15                  10
# 4    Grožđe      Zelena           5                  20
# 5    Jabuka      Crvena        1200                  19
# 6    Banana        Žuta         200                   8
# 7    Jabuka      Crvena         300                   9
# 8    Banana        Žuta         500                   5

# %%
tablica_pivot_voce = pd.pivot_table(voce_df, values=["Težina (g)","Cijena po kg (EUR)" ], index=["Ime"], aggfunc={"Težina (g)": "sum","Cijena po kg (EUR)":"mean"})

tablica_pivot_voce.columns = ["Prosjecna cijena po kg u EUR", "Ukupna Tezina (g)"]
nazivi_kolona = tablica_pivot_voce.columns
tablica_pivot_voce
# Out:
#           Prosjecna cijena po kg u EUR  Ukupna Tezina (g)
# Ime
# Banana                        4.666667                820
# Grožđe                       20.000000                  5
# Jabuka                       10.000000               1650
# Jagoda                       10.000000                 15
# Narandža                      4.000000                180

# %%
list(nazivi_kolona)
# Out:
# ['Prosjecna cijena po kg u EUR', 'Ukupna Tezina (g)']

# %%
prazna = pd.Series([])
prazna.mean()
# Out:
# nan

# %%
prazna = pd.Series([np.NaN, 5, 7])
prazna.mean()
# Out:
# 6.0

# %%
prazna.mean(skipna=False)
# Out:
# nan

# %%
help(ocjene.plot)
# Out:
# Help on PlotAccessor in module pandas.plotting._core object:
#
# class PlotAccessor(pandas.core.base.PandasObject)
#  |  PlotAccessor(data: 'Series | DataFrame') -> 'None'
#  |
#  |  Make plots of Series or DataFrame.
#  |
#  |  Uses the backend specified by the
#  |  option ``plotting.backend``. By default, matplotlib is used.
#  |
#  |  Parameters
#  |  ----------
#  |  data : Series or DataFrame
#  |      The object for which the method is called.
#  |  x : label or position, default None
#  |      Only used if data is a DataFrame.
#  |  y : label, position or list of label, positions, default None
#  |      Allows plotting of one column versus another. Only used if data is a
#  |      DataFrame.
#  |  kind : str
#  |      The kind of plot to produce:
#  |
#  |      - 'line' : line plot (default)
#  |      - 'bar' : vertical bar plot
#  |      - 'barh' : horizontal bar plot
#  |      - 'hist' : histogram
#  |      - 'box' : boxplot
# ...
