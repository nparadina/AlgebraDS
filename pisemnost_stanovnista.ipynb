# %%
import pandas as pd

literacy_rate_youth=pd.read_csv(r'C:\Users\nikap\Desktop\Data\Data\Pismenost stanovnistva\literacy_rate_youth_total_percent_of_people_ages_15_24.csv')
literacy_rate_adult=pd.read_csv(r'C:\Users\nikap\Desktop\Data\Data\Pismenost stanovnistva\literacy_rate_adult_total_percent_of_people_ages_15_and_above.csv')
out_of_school_children=pd.read_csv(r'C:\Users\nikap\Desktop\Data\Data\Pismenost stanovnistva\out-of-school-children-of-primary-school-age-by-world-region.csv')

# %%
literacy_rate_youth
# Out:
#           country  1975  1976  1977  1978  1979  1980  1981  1982  1983  ...  \
# 0           Aruba   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1     Afghanistan   NaN   NaN   NaN   NaN  30.1   NaN   NaN   NaN   NaN  ...
# 2          Angola   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 3        Anguilla   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 4         Albania   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ..            ...   ...   ...   ...   ...   ...   ...   ...   ...   ...  ...
# 150         Samoa   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 151         Yemen   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 152  South Africa   NaN   NaN   NaN   NaN   NaN  85.2   NaN   NaN   NaN  ...
# 153        Zambia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 154      Zimbabwe   NaN   NaN   NaN   NaN   NaN   NaN   NaN  89.0   NaN  ...
#
# ...

# %% [markdown]
# Uzet cemo podatke samo u zadnjih 5 godina koje imamo
# Znaci 2007, 2008,2009,2010 i 2011

# %%
literacy_rate_youth_5y=literacy_rate_youth[['country','2007', '2008', '2009', '2010','2011']]
literacy_rate_adult_5y=literacy_rate_adult[['country','2007', '2008', '2009', '2010','2011']]
literacy_rate_adult_5y
# Out:
#           country  2007  2008  2009  2010  2011
# 0           Aruba   NaN   NaN   NaN  96.8   NaN
# 1     Afghanistan   NaN   NaN   NaN   NaN  39.0
# 2          Angola   NaN   NaN   NaN   NaN  70.4
# 3        Anguilla   NaN   NaN   NaN   NaN   NaN
# 4         Albania   NaN  95.9   NaN   NaN  96.8
# ..            ...   ...   ...   ...   ...   ...
# 151         Samoa   NaN   NaN   NaN   NaN  98.8
# 152         Yemen   NaN   NaN   NaN   NaN  65.3
# 153  South Africa  88.7   NaN   NaN   NaN  93.0
# 154        Zambia  61.4   NaN   NaN   NaN   NaN
# 155      Zimbabwe   NaN   NaN   NaN   NaN  83.6
#
# [156 rows x 6 columns]

# %%
literacy_rate_youth_5y_clean=literacy_rate_youth_5y.dropna()
literacy_rate_youth_5y_clean
# Out:
#        country  2007  2008  2009  2010  2011
# 30    Colombia  98.0  98.0  97.9  98.1  98.2
# 85      Mexico  98.2  98.4  98.5  98.4  98.5
# 114  Palestine  99.1  99.2  99.2  99.2  99.3

# %%
literacy_rate_adult_5y_clean=literacy_rate_adult_5y.dropna()
literacy_rate_adult_5y_clean
# Out:
#        country  2007  2008  2009  2010  2011
# 31    Colombia  92.7  93.4  93.2  93.4  93.6
# 86      Mexico  92.8  92.9  93.4  93.1  93.5
# 115  Palestine  93.9  94.1  94.6  94.9  95.3

# %% [markdown]
# Postoje samo 3 zemljem koje podatke o pisemnosit imaju i za sve godine pa cemo na njima izvlaiti zakljucke.
#
# 1. Iz podataka za mlade:
# Postotak pismenih u Columbiji, Mexicu i Palestini stagnira.
# 2. Iz podataka za odrasle:
# Za odrasle u Columbiji i Mexiku takoder stagnira, dok u Palestini je primjetan mali kontinuirani porast u 5 godina.

# %%
out_of_school_children.Year=out_of_school_children.Year.astype("datetime64[Y]")
#out_of_school_children_extact=out_of_school_children[(out_of_school_children.Entity.isin(["Colombia","Mexico","Palestine"]))]
#out_of_school_children_extact
out_of_school_children_extact=out_of_school_children[(out_of_school_children.Year.isin(["2007","2008","2009","2010","2011"]))]
out_of_school_children_extact
#print(out_of_school_children_extact)
#out_of_school_children_extact_2=out_of_school_children_extact[out_of_school_children_extact.Year.isin(["2007","2008","2009","2010","2011"])]
# Out:
# C:\Users\nikap\AppData\Local\Temp\ipykernel_19524\4224767498.py:4: FutureWarning: The behavior of 'isin' with dtype=datetime64[s] and castable values (e.g. strings) is deprecated. In a future version, these will not be considered matching by isin. Explicitly cast to the appropriate dtype before calling isin instead.
#   out_of_school_children_extact=out_of_school_children[(out_of_school_children.Year.isin(["2007","2008","2009","2010","2011"]))]
# Empty DataFrame
# Columns: [Entity, Code, Year, Out-of-school children of primary school age, both sexes (number)]
# Index: []
